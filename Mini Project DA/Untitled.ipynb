# %%
import pandas as pd
ds = pd.read_csv("Restaurant reviews.csv")

# %%
ds
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review Rating  \
# 0     The ambience was good, food was quite good . h...      5
# 1     Ambience is too good for a pleasant evening. S...      5
# 2     A must try.. great food great ambience. Thnx f...      5
# 3     Soumen das and Arun was a great guy. Only beca...      5
# 4     Food is good.we ordered Kodi drumsticks and ba...      5
# ...                                                 ...    ...
# 9995  Madhumathi Mahajan Well to start with nice cou...      3
# 9996  This place has never disappointed us.. The foo...    4.5
# 9997  Bad rating is mainly because of "Chicken Bone ...    1.5
# 9998  I personally love and prefer Chinese Food. Had...      4
# 9999  Checked in here to try some delicious chinese ...    3.5
#
#                           Metadata             Time  Pictures    7514
# 0           1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1          3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2          2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3            1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4          3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...                            ...              ...       ...     ...
# 9995     53 Reviews , 54 Followers    6/5/2016 0:08         0     NaN
# 9996      2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
# 9997    65 Reviews , 423 Followers   6/3/2016 10:37         3     NaN
# 9998    13 Reviews , 144 Followers  5/31/2016 17:22         0     NaN
# 9999  472 Reviews , 1302 Followers  5/31/2016 16:41         6     NaN
#
# [10000 rows x 8 columns]

# %%
#             1. Data Exploration: (All)

# 1. Load the given dataset into a DataFrame.
df= pd.DataFrame(ds)
df
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review Rating  \
# 0     The ambience was good, food was quite good . h...      5
# 1     Ambience is too good for a pleasant evening. S...      5
# 2     A must try.. great food great ambience. Thnx f...      5
# 3     Soumen das and Arun was a great guy. Only beca...      5
# 4     Food is good.we ordered Kodi drumsticks and ba...      5
# ...                                                 ...    ...
# 9995  Madhumathi Mahajan Well to start with nice cou...      3
# 9996  This place has never disappointed us.. The foo...    4.5
# 9997  Bad rating is mainly because of "Chicken Bone ...    1.5
# 9998  I personally love and prefer Chinese Food. Had...      4
# 9999  Checked in here to try some delicious chinese ...    3.5
#
#                           Metadata             Time  Pictures    7514
# 0           1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1          3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2          2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3            1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4          3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...                            ...              ...       ...     ...
# 9995     53 Reviews , 54 Followers    6/5/2016 0:08         0     NaN
# 9996      2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
# 9997    65 Reviews , 423 Followers   6/3/2016 10:37         3     NaN
# 9998    13 Reviews , 144 Followers  5/31/2016 17:22         0     NaN
# 9999  472 Reviews , 1302 Followers  5/31/2016 16:41         6     NaN
#
# [10000 rows x 8 columns]

# %%
# 2. Display the first 5 and last 5 rows of the dataset.
df.head()
# Out:
#         Restaurant              Reviewer  \
# 0  Beyond Flavours     Rusha Chakraborty
# 1  Beyond Flavours  Anusha Tirumalaneedi
# 2  Beyond Flavours       Ashok Shekhawat
# 3  Beyond Flavours        Swapnil Sarkar
# 4  Beyond Flavours                Dileep
#
#                                               Review Rating  \
# 0  The ambience was good, food was quite good . h...      5
# 1  Ambience is too good for a pleasant evening. S...      5
# 2  A must try.. great food great ambience. Thnx f...      5
# 3  Soumen das and Arun was a great guy. Only beca...      5
# 4  Food is good.we ordered Kodi drumsticks and ba...      5
#
#                   Metadata             Time  Pictures    7514
# 0   1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1  3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2  2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3    1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4  3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN

# %%
df.tail()
# Out:
#             Restaurant          Reviewer  \
# 9995  Chinese Pavilion  Abhishek Mahajan
# 9996  Chinese Pavilion    Sharad Agrawal
# 9997  Chinese Pavilion         Ramandeep
# 9998  Chinese Pavilion   Nayana Shanbhag
# 9999  Chinese Pavilion  Bhargava Krishna
#
#                                                  Review Rating  \
# 9995  Madhumathi Mahajan Well to start with nice cou...      3
# 9996  This place has never disappointed us.. The foo...    4.5
# 9997  Bad rating is mainly because of "Chicken Bone ...    1.5
# 9998  I personally love and prefer Chinese Food. Had...      4
# 9999  Checked in here to try some delicious chinese ...    3.5
#
#                           Metadata             Time  Pictures  7514
# 9995     53 Reviews , 54 Followers    6/5/2016 0:08         0   NaN
# 9996      2 Reviews , 53 Followers   6/4/2016 22:01         0   NaN
# 9997    65 Reviews , 423 Followers   6/3/2016 10:37         3   NaN
# 9998    13 Reviews , 144 Followers  5/31/2016 17:22         0   NaN
# 9999  472 Reviews , 1302 Followers  5/31/2016 16:41         6   NaN

# %%
# 3. Check the shape of the dataset (rows and columns).
df.shape
# Out:
# (10000, 8)

# %%
# 4. List the column names and data types of the dataset.
df.dtypes
# Out:
# Restaurant     object
# Reviewer       object
# Review         object
# Rating         object
# Metadata       object
# Time           object
# Pictures        int64
# 7514          float64
# dtype: object

# %%
# 5. Check for missing values in the dataset and count them.
df.isnull().sum().sum()
# Out:
# 10196

# %%
# 6. Display summary statistics (mean, median, std, etc.) for the numerical columns.
df["Rating"] = pd.to_numeric(df["Rating"], errors="coerce")
df["Rating"].mean()
# Out:
# 3.601044071880333

# %%
df["Rating"].median()
# Out:
# 4.0

# %%
df["Rating"].std()
# Out:
# 1.4834613390117264

# %%
df["Rating"].value_counts()
# Out:
# Rating
# 5.0    3832
# 4.0    2373
# 1.0    1735
# 3.0    1193
# 2.0     684
# 4.5      69
# 3.5      47
# 2.5      19
# 1.5       9
# Name: count, dtype: int64

# %%
# 7. Identify any duplicate rows in the dataset and remove them.
df[df.duplicated()]
# Out:
#                Restaurant Reviewer Review  Rating Metadata Time  Pictures  \
# 8778  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8779  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8780  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8781  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8782  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8783  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8784  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8785  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8786  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8787  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8788  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8789  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8790  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8791  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8792  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8793  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8794  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8795  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8796  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8797  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8798  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 8799  American Wild Wings      NaN    NaN     NaN      NaN  NaN         0
# 9086         Arena Eleven      NaN    NaN     NaN      NaN  NaN         0
# 9087         Arena Eleven      NaN    NaN     NaN      NaN  NaN         0
# 9088         Arena Eleven      NaN    NaN     NaN      NaN  NaN         0
# 9089         Arena Eleven      NaN    NaN     NaN      NaN  NaN         0
# 9090         Arena Eleven      NaN    NaN     NaN      NaN  NaN         0
# 9091         Arena Eleven      NaN    NaN     NaN      NaN  NaN         0
# 9092         Arena Eleven      NaN    NaN     NaN      NaN  NaN         0
# 9093         Arena Eleven      NaN    NaN     NaN      NaN  NaN         0
# 9094         Arena Eleven      NaN    NaN     NaN      NaN  NaN         0
# 9095         Arena Eleven      NaN    NaN     NaN      NaN  NaN         0
# 9096         Arena Eleven      NaN    NaN     NaN      NaN  NaN         0
# 9097         Arena Eleven      NaN    NaN     NaN      NaN  NaN         0
# 9098         Arena Eleven      NaN    NaN     NaN      NaN  NaN         0
# 9099         Arena Eleven      NaN    NaN     NaN      NaN  NaN         0
#
#       7514
# 8778   NaN
# 8779   NaN
# 8780   NaN
# 8781   NaN
# 8782   NaN
# 8783   NaN
# 8784   NaN
# 8785   NaN
# 8786   NaN
# 8787   NaN
# 8788   NaN
# 8789   NaN
# 8790   NaN
# 8791   NaN
# 8792   NaN
# 8793   NaN
# 8794   NaN
# 8795   NaN
# 8796   NaN
# 8797   NaN
# 8798   NaN
# 8799   NaN
# 9086   NaN
# 9087   NaN
# 9088   NaN
# 9089   NaN
# 9090   NaN
# 9091   NaN
# 9092   NaN
# 9093   NaN
# 9094   NaN
# 9095   NaN
# 9096   NaN
# 9097   NaN
# 9098   NaN
# 9099   NaN

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# 8. Get the number of unique values in each column.
df.nunique()
# Out:
# Restaurant     100
# Reviewer      7446
# Review        9364
# Rating           9
# Metadata      2477
# Time          9782
# Pictures        36
# 7514             1
# dtype: int64

# %%
                            #  Data Cleaning: (Any 5)
# 1. Fill any missing values in numerical columns with the mean of the respective column.
df1= df["Rating"].fillna(df["Rating"].mean())
df1.isnull().sum()
# Out:
# 0

# %%
# 2. Drop rows with any missing values.
df2= df.dropna()
df2
# Out:
#         Restaurant           Reviewer  \
# 0  Beyond Flavours  Rusha Chakraborty
#
#                                               Review  Rating  \
# 0  The ambience was good, food was quite good . h...     5.0
#
#                  Metadata             Time  Pictures    7514
# 0  1 Review , 2 Followers  5/25/2019 15:54         0  2447.0

# %%
df
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review  Rating  \
# 0     The ambience was good, food was quite good . h...     5.0
# 1     Ambience is too good for a pleasant evening. S...     5.0
# 2     A must try.. great food great ambience. Thnx f...     5.0
# 3     Soumen das and Arun was a great guy. Only beca...     5.0
# 4     Food is good.we ordered Kodi drumsticks and ba...     5.0
# ...                                                 ...     ...
# 9995  Madhumathi Mahajan Well to start with nice cou...     3.0
# 9996  This place has never disappointed us.. The foo...     4.5
# 9997  Bad rating is mainly because of "Chicken Bone ...     1.5
# 9998  I personally love and prefer Chinese Food. Had...     4.0
# 9999  Checked in here to try some delicious chinese ...     3.5
#
#                           Metadata             Time  Pictures    7514
# 0           1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1          3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2          2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3            1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4          3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...                            ...              ...       ...     ...
# 9995     53 Reviews , 54 Followers    6/5/2016 0:08         0     NaN
# 9996      2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
# 9997    65 Reviews , 423 Followers   6/3/2016 10:37         3     NaN
# 9998    13 Reviews , 144 Followers  5/31/2016 17:22         0     NaN
# 9999  472 Reviews , 1302 Followers  5/31/2016 16:41         6     NaN
#
# [9964 rows x 8 columns]

# %%
# 3. Replace all occurrences of a specific value in a column (e.g., replace 'NA' with NaN).
df3= df["Rating"].replace({4.0:4.5})
df3
# Out:
# 0       5.0
# 1       5.0
# 2       5.0
# 3       5.0
# 4       5.0
#        ...
# 9995    3.0
# 9996    4.5
# 9997    1.5
# 9998    4.5
# 9999    3.5
# Name: Rating, Length: 9964, dtype: float64

# %%
# 4. Remove a specific column from the dataset.
df4= df.drop(columns=["7514"])
df4
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review  Rating  \
# 0     The ambience was good, food was quite good . h...     5.0
# 1     Ambience is too good for a pleasant evening. S...     5.0
# 2     A must try.. great food great ambience. Thnx f...     5.0
# 3     Soumen das and Arun was a great guy. Only beca...     5.0
# 4     Food is good.we ordered Kodi drumsticks and ba...     5.0
# ...                                                 ...     ...
# 9995  Madhumathi Mahajan Well to start with nice cou...     3.0
# 9996  This place has never disappointed us.. The foo...     4.5
# 9997  Bad rating is mainly because of "Chicken Bone ...     1.5
# 9998  I personally love and prefer Chinese Food. Had...     4.0
# 9999  Checked in here to try some delicious chinese ...     3.5
#
#                           Metadata             Time  Pictures
# 0           1 Review , 2 Followers  5/25/2019 15:54         0
# 1          3 Reviews , 2 Followers  5/25/2019 14:20         0
# 2          2 Reviews , 3 Followers  5/24/2019 22:54         0
# 3            1 Review , 1 Follower  5/24/2019 22:11         0
# 4          3 Reviews , 2 Followers  5/24/2019 21:37         0
# ...                            ...              ...       ...
# 9995     53 Reviews , 54 Followers    6/5/2016 0:08         0
# 9996      2 Reviews , 53 Followers   6/4/2016 22:01         0
# 9997    65 Reviews , 423 Followers   6/3/2016 10:37         3
# 9998    13 Reviews , 144 Followers  5/31/2016 17:22         0
# 9999  472 Reviews , 1302 Followers  5/31/2016 16:41         6
#
# [9964 rows x 7 columns]

# %%
# 5. Rename a column from old_name to new_name.
df.rename(columns= {"Pictures":"No of Pictures"})
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review  Rating  \
# 0     The ambience was good, food was quite good . h...     5.0
# 1     Ambience is too good for a pleasant evening. S...     5.0
# 2     A must try.. great food great ambience. Thnx f...     5.0
# 3     Soumen das and Arun was a great guy. Only beca...     5.0
# 4     Food is good.we ordered Kodi drumsticks and ba...     5.0
# ...                                                 ...     ...
# 9995  Madhumathi Mahajan Well to start with nice cou...     3.0
# 9996  This place has never disappointed us.. The foo...     4.5
# 9997  Bad rating is mainly because of "Chicken Bone ...     1.5
# 9998  I personally love and prefer Chinese Food. Had...     4.0
# 9999  Checked in here to try some delicious chinese ...     3.5
#
#                           Metadata             Time  No of Pictures    7514
# 0           1 Review , 2 Followers  5/25/2019 15:54               0  2447.0
# 1          3 Reviews , 2 Followers  5/25/2019 14:20               0     NaN
# 2          2 Reviews , 3 Followers  5/24/2019 22:54               0     NaN
# 3            1 Review , 1 Follower  5/24/2019 22:11               0     NaN
# 4          3 Reviews , 2 Followers  5/24/2019 21:37               0     NaN
# ...                            ...              ...             ...     ...
# 9995     53 Reviews , 54 Followers    6/5/2016 0:08               0     NaN
# 9996      2 Reviews , 53 Followers   6/4/2016 22:01               0     NaN
# 9997    65 Reviews , 423 Followers   6/3/2016 10:37               3     NaN
# 9998    13 Reviews , 144 Followers  5/31/2016 17:22               0     NaN
# 9999  472 Reviews , 1302 Followers  5/31/2016 16:41               6     NaN
#
# [9964 rows x 8 columns]

# %%
# 6. Convert a column from string format to date format.
df5= pd.to_datetime(df["Time"])
df5
# Out:
# 0      2019-05-25 15:54:00
# 1      2019-05-25 14:20:00
# 2      2019-05-24 22:54:00
# 3      2019-05-24 22:11:00
# 4      2019-05-24 21:37:00
#                ...
# 9995   2016-06-05 00:08:00
# 9996   2016-06-04 22:01:00
# 9997   2016-06-03 10:37:00
# 9998   2016-05-31 17:22:00
# 9999   2016-05-31 16:41:00
# Name: Time, Length: 9964, dtype: datetime64[ns]

# %%
# 7. Normalize a numerical column to scale the values between 0 and 1.
df6 = (df["Rating"] - df["Rating"].min()) / (df["Rating"].max() - df["Rating"].min())
df6
# Out:
# 0       1.000
# 1       1.000
# 2       1.000
# 3       1.000
# 4       1.000
#         ...
# 9995    0.500
# 9996    0.875
# 9997    0.125
# 9998    0.750
# 9999    0.625
# Name: Rating, Length: 9964, dtype: float64

# %%
#                 Data Selection and Filtering: (All) 
# 1. Select the Reviewer column from the DataFrame. 
df["Reviewer"]
# Out:
# 0          Rusha Chakraborty
# 1       Anusha Tirumalaneedi
# 2            Ashok Shekhawat
# 3             Swapnil Sarkar
# 4                     Dileep
#                 ...
# 9995        Abhishek Mahajan
# 9996          Sharad Agrawal
# 9997               Ramandeep
# 9998         Nayana Shanbhag
# 9999        Bhargava Krishna
# Name: Reviewer, Length: 9964, dtype: object

# %%
# 2. Select the Reviewer and Review columns from the DataFrame. 
df[["Reviewer","Review"]]
# Out:
#                   Reviewer                                             Review
# 0        Rusha Chakraborty  The ambience was good, food was quite good . h...
# 1     Anusha Tirumalaneedi  Ambience is too good for a pleasant evening. S...
# 2          Ashok Shekhawat  A must try.. great food great ambience. Thnx f...
# 3           Swapnil Sarkar  Soumen das and Arun was a great guy. Only beca...
# 4                   Dileep  Food is good.we ordered Kodi drumsticks and ba...
# ...                    ...                                                ...
# 9995      Abhishek Mahajan  Madhumathi Mahajan Well to start with nice cou...
# 9996        Sharad Agrawal  This place has never disappointed us.. The foo...
# 9997             Ramandeep  Bad rating is mainly because of "Chicken Bone ...
# 9998       Nayana Shanbhag  I personally love and prefer Chinese Food. Had...
# 9999      Bhargava Krishna  Checked in here to try some delicious chinese ...
#
# [9964 rows x 2 columns]

# %%
# 3. Filter the DataFrame to show rows where the Rating is greater than 4. 
df[df["Rating"]>4]
# Out:
#             Restaurant                 Reviewer  \
# 0      Beyond Flavours        Rusha Chakraborty
# 1      Beyond Flavours     Anusha Tirumalaneedi
# 2      Beyond Flavours          Ashok Shekhawat
# 3      Beyond Flavours           Swapnil Sarkar
# 4      Beyond Flavours                   Dileep
# ...                ...                      ...
# 9990  Chinese Pavilion             Akram Ul Haq
# 9991  Chinese Pavilion  Krishna Teja Ratnakaram
# 9992  Chinese Pavilion               Sujay Garg
# 9993  Chinese Pavilion              Richard Rao
# 9996  Chinese Pavilion           Sharad Agrawal
#
#                                                  Review  Rating  \
# 0     The ambience was good, food was quite good . h...     5.0
# 1     Ambience is too good for a pleasant evening. S...     5.0
# 2     A must try.. great food great ambience. Thnx f...     5.0
# 3     Soumen das and Arun was a great guy. Only beca...     5.0
# 4     Food is good.we ordered Kodi drumsticks and ba...     5.0
# ...                                                 ...     ...
# 9990  Amazing food ! I always go here when I want Ch...     5.0
# 9991  I was never a fan of Chinese food until I visi...     5.0
# 9992  I visited this restaurant with friends and was...     5.0
# 9993  Im going to cut to the chase, The food is exce...     5.0
# 9996  This place has never disappointed us.. The foo...     4.5
#
#                        Metadata             Time  Pictures    7514
# 0        1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1       3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2       2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3         1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4       3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...                         ...              ...       ...     ...
# 9990  3 Reviews , 128 Followers  6/16/2016 13:53         0     NaN
# 9991   9 Reviews , 54 Followers   6/15/2016 0:50         0     NaN
# 9992     4 Reviews , 1 Follower   6/15/2016 0:04         0     NaN
# 9993   3 Reviews , 74 Followers  6/14/2016 18:35         0     NaN
# 9996   2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
#
# [3901 rows x 8 columns]

# %%
# 4. Filter the dataset to display only rows where the Restaurant is "Chinese Pavilion".
df[df["Restaurant"]=="Chinese Pavilion"]
# Out:
#             Restaurant           Reviewer  \
# 9900  Chinese Pavilion               Khan
# 9901  Chinese Pavilion        Diaryofmuna
# 9902  Chinese Pavilion   Himanshu Chhabra
# 9903  Chinese Pavilion        Arun Prasad
# 9904  Chinese Pavilion  Rishita Mukherjee
# ...                ...                ...
# 9995  Chinese Pavilion   Abhishek Mahajan
# 9996  Chinese Pavilion     Sharad Agrawal
# 9997  Chinese Pavilion          Ramandeep
# 9998  Chinese Pavilion    Nayana Shanbhag
# 9999  Chinese Pavilion   Bhargava Krishna
#
#                                                  Review  Rating  \
# 9900  Starting off with food...They have amazing and...     5.0
# 9901  I had ordered Manchow Soup. The taste was very...     3.0
# 9902  It is overrated casual Chinese food, with lot ...     1.0
# 9903  Overrated place. It's a disappointment and bel...     2.0
# 9904  It's an good place to try out casual chinese d...     4.0
# ...                                                 ...     ...
# 9995  Madhumathi Mahajan Well to start with nice cou...     3.0
# 9996  This place has never disappointed us.. The foo...     4.5
# 9997  Bad rating is mainly because of "Chicken Bone ...     1.5
# 9998  I personally love and prefer Chinese Food. Had...     4.0
# 9999  Checked in here to try some delicious chinese ...     3.5
#
#                           Metadata             Time  Pictures  7514
# 9900                      1 Review  5/13/2019 12:05         0   NaN
# 9901     27 Reviews , 10 Followers   5/8/2019 15:02         8   NaN
# 9902      5 Reviews , 52 Followers   5/5/2019 22:59         0   NaN
# 9903      5 Reviews , 41 Followers  4/28/2019 20:37         0   NaN
# 9904    16 Reviews , 191 Followers  4/23/2019 22:53         6   NaN
# ...                            ...              ...       ...   ...
# 9995     53 Reviews , 54 Followers    6/5/2016 0:08         0   NaN
# 9996      2 Reviews , 53 Followers   6/4/2016 22:01         0   NaN
# 9997    65 Reviews , 423 Followers   6/3/2016 10:37         3   NaN
# 9998    13 Reviews , 144 Followers  5/31/2016 17:22         0   NaN
# 9999  472 Reviews , 1302 Followers  5/31/2016 16:41         6   NaN
#
# [100 rows x 8 columns]

# %%
#                     Sorting and Ordering: (All) 
# 1. Sort the DataFrame by Rating in ascending order. 
df7= df.sort_values("Rating", ascending = True)
df7
# Out:
#                          Restaurant           Reviewer  \
# 8453                        T Grill   Ramaiah Chowdary
# 4723                Shanghai Chef 2         Sai Charan
# 4728                Shanghai Chef 2             Elusha
# 1808              10 Downing Street    Meenakshi Patel
# 1807              10 Downing Street         Anjali Lal
# ...                             ...                ...
# 4864                 Udipi's Upahar             Chinnu
# 4980                  Mathura Vilas  Parakh Khandelwal
# 7601  The Old Madras Baking Company  Dhanasekar Kannan
# 8777            American Wild Wings                NaN
# 9085                   Arena Eleven                NaN
#
#                                                  Review  Rating  \
# 8453  One word YUKk !!! Uncooked, smelly grilled pra...     1.0
# 4723  Restaurant serves stored food. Today I visited...     1.0
# 4728  Worst chinese i have ever eaten !! The chopsue...     1.0
# 1808  Reading the reviews we visited this place, how...     1.0
# 1807  Most terrible place. I used to love Chennai 10...     1.0
# ...                                                 ...     ...
# 4864                                 super delivery boy     5.0
# 4980  Nice place..good ambiance..super friendly and ...     5.0
# 7601  One of the best pizzas to try. It served with ...     NaN
# 8777                                                NaN     NaN
# 9085                                                NaN     NaN
#
#                        Metadata              Time  Pictures  7514
# 8453  16 Reviews , 14 Followers   6/22/2018 13:57         0   NaN
# 4723    5 Reviews , 5 Followers   1/11/2019 20:38         0   NaN
# 4728    2 Reviews , 3 Followers  12/21/2018 23:39         0   NaN
# 1808                  2 Reviews     5/5/2019 1:17         0   NaN
# 1807     4 Reviews , 1 Follower    5/5/2019 11:43         0   NaN
# ...                         ...               ...       ...   ...
# 4864                  6 Reviews   7/20/2018 10:17         0   NaN
# 4980  16 Reviews , 68 Followers  10/16/2018 23:20         0   NaN
# 7601  12 Reviews , 21 Followers   5/18/2019 12:31         1   NaN
# 8777                        NaN               NaN         0   NaN
# 9085                        NaN               NaN         0   NaN
#
# [9964 rows x 8 columns]

# %%
# 2. Sort the column alphabetically (for example, City). 
df8= df.sort_values(by=["Restaurant","Reviewer"], ascending= [True,True])
df8
# Out:
#              Restaurant             Reviewer  \
# 1846  10 Downing Street       Aanchal Khemka
# 1896  10 Downing Street            Abhimanyu
# 1869  10 Downing Street       Abhisek Mishra
# 1871  10 Downing Street       Abhishek Singh
# 1889  10 Downing Street               Aditya
# ...                 ...                  ...
# 637             eat.fit  Thehungryhyderabadi
# 638             eat.fit             Vaishali
# 629             eat.fit          Vinay Kumar
# 628             eat.fit      Vishwanth Reddy
# 621             eat.fit           Zarar Khan
#
#                                                  Review  Rating  \
# 1846  We went here for lunch on a girls day out and ...     4.0
# 1896  I have been to quite a few similar places in H...     5.0
# 1869  The ambience along with the roof top view was ...     5.0
# 1871  Great place and a really amazing crowd. The am...     4.0
# 1889  Food is just average but the ambiance and the ...     4.0
# ...                                                 ...     ...
# 637   Ordered the breakfast combo from zomato. The t...     3.0
# 638   I ordered from this place from Zomato. The amo...     1.0
# 629                    Forgot to give spoon and tissues     3.0
# 628   Why on earth would someone charge 185 rs for 3...     2.0
# 621   The food from this restaurant was lipsmacking ...     4.0
#
#                           Metadata              Time  Pictures  7514
# 1846  189 Reviews , 2321 Followers    2/3/2019 22:04         2   NaN
# 1896        5 Reviews , 1 Follower  10/23/2018 20:01         0   NaN
# 1869      5 Reviews , 65 Followers  12/26/2018 10:52         0   NaN
# 1871     8 Reviews , 128 Followers   12/21/2018 5:47         0   NaN
# 1889    57 Reviews , 310 Followers   11/1/2018 13:45         1   NaN
# ...                            ...               ...       ...   ...
# 637    145 Reviews , 248 Followers     4/7/2019 1:36         0   NaN
# 638      23 Reviews , 26 Followers    4/6/2019 19:05         1   NaN
# 629         2 Reviews , 1 Follower   4/15/2019 19:41         0   NaN
# 628      23 Reviews , 14 Followers   4/16/2019 16:10         0   NaN
# 621     78 Reviews , 418 Followers   4/30/2019 10:09         1   NaN
#
# [9964 rows x 8 columns]

# %%
# 3. Sort the column in descending order (for example, Pictures). 
df9= df.sort_values(by= "Pictures", ascending = False)
df9
# Out:
#                                Restaurant            Reviewer  \
# 9043                         Arena Eleven  Anvith Devulapally
# 3148                          Pista House         Food Nawabs
# 4697                           Ulavacharu         Food Nawabs
# 6080                           PourHouse7             Akshith
# 3998                        Deli 9 Bistro         Food Nawabs
# ...                                   ...                 ...
# 3627  Banana Leaf Multicuisine Restaurant            Bindusha
# 3626  Banana Leaf Multicuisine Restaurant               Vinay
# 3623  Banana Leaf Multicuisine Restaurant       Krithika Swag
# 3622  Banana Leaf Multicuisine Restaurant               Nillu
# 4982                        Mathura Vilas             Harry N
#
#                                                  Review  Rating  \
# 9043  Rating: 3.5\n\nReplacing Serafina, Arena Eleve...     4.0
# 3148  An amazing pocket friendly place where they se...     4.0
# 4697  India is a food nation, every 50 kms you trave...     4.0
# 6080  I visited this place along with my friends tod...     5.0
# 3998  It's all about Food, a small and a ambience fi...     4.0
# ...                                                 ...     ...
# 3627  The food at this place is so good where you ca...     4.0
# 3626  Sometimes Non Veg combo is the thali which I p...     4.0
# 3623  I am in love the delicacy food served here. Th...     5.0
# 3622  If you are having low budget then this is the ...     4.0
# 4982  We visited this place many times. Not so crowd...     3.0
#
#                           Metadata              Time  Pictures  7514
# 9043  124 Reviews , 1035 Followers   4/22/2019 18:23        64   NaN
# 3148  130 Reviews , 5532 Followers   10/8/2018 15:15        52   NaN
# 4697  130 Reviews , 5532 Followers    10/5/2018 8:56        42   NaN
# 6080     54 Reviews , 63 Followers   2/16/2019 20:40        42   NaN
# 3998  130 Reviews , 5532 Followers  10/10/2018 13:52        41   NaN
# ...                            ...               ...       ...   ...
# 3627        4 Reviews , 1 Follower  12/23/2018 22:03         0   NaN
# 3626                     5 Reviews   12/24/2018 0:22         0   NaN
# 3623         1 Review , 1 Follower   1/11/2019 13:21         0   NaN
# 3622      17 Reviews , 9 Followers    1/16/2019 0:51         0   NaN
# 4982      28 Reviews , 9 Followers  10/16/2018 14:33         0   NaN
#
# [9964 rows x 8 columns]

# %%
# 4. Sort the DataFrame by Restaurant first and then by Rating. 
df10= df.sort_values(by= ["Restaurant","Rating"], ascending= [True,True])
df10
# Out:
#              Restaurant            Reviewer  \
# 1806  10 Downing Street      K Prakash Raju
# 1807  10 Downing Street          Anjali Lal
# 1808  10 Downing Street     Meenakshi Patel
# 1832  10 Downing Street       Joyofcalcutta
# 1857  10 Downing Street       Aditya Chopra
# ...                 ...                 ...
# 690             eat.fit       Saloni Gupta🧁
# 693             eat.fit           Siva Raju
# 694             eat.fit      Rasheed Khan.M
# 698             eat.fit  Nishtha Chandarana
# 699             eat.fit              Naveen
#
#                                                  Review  Rating  \
# 1806  I came there with my friend as stags. It was w...     1.0
# 1807  Most terrible place. I used to love Chennai 10...     1.0
# 1808  Reading the reviews we visited this place, how...     1.0
# 1832  Definitely one of the worst places to go for f...     1.0
# 1857  My friend and I visited this place on the 13th...     1.0
# ...                                                 ...     ...
# 690   Ordered the paneer-dal combo for 2 people. It ...     5.0
# 693   Quality of food and packing is good.. Quantity...     5.0
# 694   Great food came up with neatly packed and the ...     5.0
# 698   Eat fit - name itself suggest healthy food..\n...     5.0
# 699   Eat. Fit surprised me the way they packed the ...     5.0
#
#                           Metadata             Time  Pictures  7514
# 1806                      1 Review   5/5/2019 19:54         0   NaN
# 1807        4 Reviews , 1 Follower   5/5/2019 11:43         0   NaN
# 1808                     2 Reviews    5/5/2019 1:17         0   NaN
# 1832        2 Reviews , 1 Follower   3/12/2019 9:04         0   NaN
# 1857   87 Reviews , 1165 Followers   1/15/2019 8:45         0   NaN
# ...                            ...              ...       ...   ...
# 690    166 Reviews , 980 Followers  2/19/2019 22:09         3   NaN
# 693       4 Reviews , 20 Followers  2/18/2019 12:06         0   NaN
# 694       25 Reviews , 2 Followers   2/18/2019 9:33         0   NaN
# 698   151 Reviews , 2116 Followers  2/14/2019 19:28         3   NaN
# 699                      7 Reviews  2/12/2019 20:34         0   NaN
#
# [9964 rows x 8 columns]

# %%
# 5. Sort the DataFrame by Age and keep only the Pictures 3 rows.
df11= df.sort_values(by= "Pictures", ascending = False).head(3)
df11
# Out:
#         Restaurant            Reviewer  \
# 9043  Arena Eleven  Anvith Devulapally
# 3148   Pista House         Food Nawabs
# 4697    Ulavacharu         Food Nawabs
#
#                                                  Review  Rating  \
# 9043  Rating: 3.5\n\nReplacing Serafina, Arena Eleve...     4.0
# 3148  An amazing pocket friendly place where they se...     4.0
# 4697  India is a food nation, every 50 kms you trave...     4.0
#
#                           Metadata             Time  Pictures  7514
# 9043  124 Reviews , 1035 Followers  4/22/2019 18:23        64   NaN
# 3148  130 Reviews , 5532 Followers  10/8/2018 15:15        52   NaN
# 4697  130 Reviews , 5532 Followers   10/5/2018 8:56        42   NaN

# %%
#                 Renaming Columns: (All) 
# 1. Rename the Time column to Date and Time. 
df.rename(columns= {"Time":"Date and Time"})
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review  Rating  \
# 0     The ambience was good, food was quite good . h...     5.0
# 1     Ambience is too good for a pleasant evening. S...     5.0
# 2     A must try.. great food great ambience. Thnx f...     5.0
# 3     Soumen das and Arun was a great guy. Only beca...     5.0
# 4     Food is good.we ordered Kodi drumsticks and ba...     5.0
# ...                                                 ...     ...
# 9995  Madhumathi Mahajan Well to start with nice cou...     3.0
# 9996  This place has never disappointed us.. The foo...     4.5
# 9997  Bad rating is mainly because of "Chicken Bone ...     1.5
# 9998  I personally love and prefer Chinese Food. Had...     4.0
# 9999  Checked in here to try some delicious chinese ...     3.5
#
#                           Metadata    Date and Time  Pictures    7514
# 0           1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1          3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2          2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3            1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4          3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...                            ...              ...       ...     ...
# 9995     53 Reviews , 54 Followers    6/5/2016 0:08         0     NaN
# 9996      2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
# 9997    65 Reviews , 423 Followers   6/3/2016 10:37         3     NaN
# 9998    13 Reviews , 144 Followers  5/31/2016 17:22         0     NaN
# 9999  472 Reviews , 1302 Followers  5/31/2016 16:41         6     NaN
#
# [9964 rows x 8 columns]

# %%
# 2. Rename the 7514 column to Other. 
df.rename(columns= {"7514":"Other"})
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review  Rating  \
# 0     The ambience was good, food was quite good . h...     5.0
# 1     Ambience is too good for a pleasant evening. S...     5.0
# 2     A must try.. great food great ambience. Thnx f...     5.0
# 3     Soumen das and Arun was a great guy. Only beca...     5.0
# 4     Food is good.we ordered Kodi drumsticks and ba...     5.0
# ...                                                 ...     ...
# 9995  Madhumathi Mahajan Well to start with nice cou...     3.0
# 9996  This place has never disappointed us.. The foo...     4.5
# 9997  Bad rating is mainly because of "Chicken Bone ...     1.5
# 9998  I personally love and prefer Chinese Food. Had...     4.0
# 9999  Checked in here to try some delicious chinese ...     3.5
#
#                           Metadata             Time  Pictures   Other
# 0           1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1          3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2          2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3            1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4          3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...                            ...              ...       ...     ...
# 9995     53 Reviews , 54 Followers    6/5/2016 0:08         0     NaN
# 9996      2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
# 9997    65 Reviews , 423 Followers   6/3/2016 10:37         3     NaN
# 9998    13 Reviews , 144 Followers  5/31/2016 17:22         0     NaN
# 9999  472 Reviews , 1302 Followers  5/31/2016 16:41         6     NaN
#
# [9964 rows x 8 columns]

# %%
# 3. Rename multiple columns at once (e.g., Time to Date and Time and 7514 to Other). 
dfcopy = df
dfcopy= dfcopy.rename(columns= {"Time":"Date and Time","7514":"Other"})
dfcopy
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review  Rating  \
# 0     The ambience was good, food was quite good . h...     5.0
# 1     Ambience is too good for a pleasant evening. S...     5.0
# 2     A must try.. great food great ambience. Thnx f...     5.0
# 3     Soumen das and Arun was a great guy. Only beca...     5.0
# 4     Food is good.we ordered Kodi drumsticks and ba...     5.0
# ...                                                 ...     ...
# 9995  Madhumathi Mahajan Well to start with nice cou...     3.0
# 9996  This place has never disappointed us.. The foo...     4.5
# 9997  Bad rating is mainly because of "Chicken Bone ...     1.5
# 9998  I personally love and prefer Chinese Food. Had...     4.0
# 9999  Checked in here to try some delicious chinese ...     3.5
#
#                           Metadata    Date and Time  Pictures   Other
# 0           1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1          3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2          2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3            1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4          3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...                            ...              ...       ...     ...
# 9995     53 Reviews , 54 Followers    6/5/2016 0:08         0     NaN
# 9996      2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
# 9997    65 Reviews , 423 Followers   6/3/2016 10:37         3     NaN
# 9998    13 Reviews , 144 Followers  5/31/2016 17:22         0     NaN
# 9999  472 Reviews , 1302 Followers  5/31/2016 16:41         6     NaN
#
# [9964 rows x 8 columns]

# %%
# 4. Change the column name to a simpler one (e.g., Product_Price to Price). 
dfcopy.rename(columns= {"Date and Time":"DateTime"})
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review  Rating  \
# 0     The ambience was good, food was quite good . h...     5.0
# 1     Ambience is too good for a pleasant evening. S...     5.0
# 2     A must try.. great food great ambience. Thnx f...     5.0
# 3     Soumen das and Arun was a great guy. Only beca...     5.0
# 4     Food is good.we ordered Kodi drumsticks and ba...     5.0
# ...                                                 ...     ...
# 9995  Madhumathi Mahajan Well to start with nice cou...     3.0
# 9996  This place has never disappointed us.. The foo...     4.5
# 9997  Bad rating is mainly because of "Chicken Bone ...     1.5
# 9998  I personally love and prefer Chinese Food. Had...     4.0
# 9999  Checked in here to try some delicious chinese ...     3.5
#
#                           Metadata         DateTime  Pictures   Other
# 0           1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1          3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2          2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3            1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4          3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...                            ...              ...       ...     ...
# 9995     53 Reviews , 54 Followers    6/5/2016 0:08         0     NaN
# 9996      2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
# 9997    65 Reviews , 423 Followers   6/3/2016 10:37         3     NaN
# 9998    13 Reviews , 144 Followers  5/31/2016 17:22         0     NaN
# 9999  472 Reviews , 1302 Followers  5/31/2016 16:41         6     NaN
#
# [9964 rows x 8 columns]

# %%
#                 Data Aggregation: (Any 5) 
# 1. Find the average of the Pictures column. 
pd.to_numeric(df["Pictures"]).mean()
# Out:
# 0.7513046969088719

# %%
# 2. Find the total sum of the Pictures column. 
df["Pictures"].sum()
# Out:
# 7486

# %%
# 3. Count how many times each value appears in the Restaurant column. 
df["Restaurant"].value_counts()
# Out:
# Restaurant
# Beyond Flavours                   100
# Driven Cafe                       100
# Eat India Company                 100
# Urban Asia - Kitchen & Bar        100
# The Indi Grill                    100
#                                  ...
# Hunger Maggi Point                100
# Behrouz Biryani                   100
# 3B's - Buddies, Bar & Barbecue    100
# Arena Eleven                       86
# American Wild Wings                78
# Name: count, Length: 100, dtype: int64

# %%
# 4. Calculate the total sum of Rating for each unique value in the Restaurant column. 
df.groupby("Restaurant")["Rating"].sum()
# Out:
# Restaurant
# 10 Downing Street                        380.0
# 13 Dhaba                                 348.0
# 3B's - Buddies, Bar & Barbecue           476.0
# AB's - Absolute Barbecues                488.0
# Absolute Sizzlers                        362.0
#                                          ...
# Urban Asia - Kitchen & Bar               365.0
# Yum Yum Tree - The Arabian Food Court    356.0
# Zega - Sheraton Hyderabad Hotel          445.0
# Zing's Northeast Kitchen                 365.0
# eat.fit                                  320.0
# Name: Rating, Length: 100, dtype: float64

# %%
# 5. Find the highest Pictures in the dataset. 
df["Pictures"].max()
# Out:
# 64

# %%
# 6. Calculate the minimum Pictures in the dataset.
df["Pictures"].min()
# Out:
# 0

# %%
df["Restaurant"].unique()[0:5]
# Out:
# array(['Beyond Flavours', 'Paradise', 'Flechazo',
#        'Shah Ghouse Hotel & Restaurant', 'Over The Moon Brew Company'],
#       dtype=object)

# %%
#                 Simple Data Visualization: (Any 5) 
# 1. Create a simple bar plot of Restaurant vs. Average Rating. 
import matplotlib.pyplot as plt
import numpy as np

avgRating = df.groupby("Restaurant")["Rating"].mean().head()
restaurant= df["Restaurant"].unique()[0:5]
plt.bar(restaurant, avgRating)
plt.show()

# %%
# 2. Create a line plot for Average Rating over Restaurant. 
avgRating = df.groupby("Restaurant")["Rating"].mean()
restaurant= df["Restaurant"].unique()
plt.figure(figsize=(15,5))
plt.plot(restaurant, avgRating, marker= "o", linestyle= "-")
plt.xlabel("Restaurant")
plt.ylabel("Average Rating")
plt.show()

# %%
# 3. Create a histogram for the Rating column. 
plt.hist(df["Rating"])
plt.xlabel("Rating")
plt.ylabel("Instances")
plt.show()

# %%
# 4. Create a pie chart to show the distribution of values in the Pictures column. 
plt.pie(df["Rating"].value_counts(),labels= df["Rating"].value_counts().index,autopct="%1.1f%%", startangle=0)
plt.show()

# %%
# 5. Create a scatter plot between Age and Price. 
avgRating = df.groupby("Restaurant")["Rating"].mean()
restaurant= df["Restaurant"].unique()
plt.figure(figsize=(15,5))
plt.scatter(restaurant, avgRating, marker= "o")
plt.xlabel("Restaurant")
plt.ylabel("Average Rating")
plt.show()

# %%
# 6. Display a box plot for the Rating column. 
plt.boxplot(df["Pictures"], vert=False, patch_artist=True)
plt.show()

# %%
df
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review  Rating  \
# 0     The ambience was good, food was quite good . h...     5.0
# 1     Ambience is too good for a pleasant evening. S...     5.0
# 2     A must try.. great food great ambience. Thnx f...     5.0
# 3     Soumen das and Arun was a great guy. Only beca...     5.0
# 4     Food is good.we ordered Kodi drumsticks and ba...     5.0
# ...                                                 ...     ...
# 9995  Madhumathi Mahajan Well to start with nice cou...     3.0
# 9996  This place has never disappointed us.. The foo...     4.5
# 9997  Bad rating is mainly because of "Chicken Bone ...     1.5
# 9998  I personally love and prefer Chinese Food. Had...     4.0
# 9999  Checked in here to try some delicious chinese ...     3.5
#
#                           Metadata             Time  Pictures    7514
# 0           1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1          3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2          2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3            1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4          3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...                            ...              ...       ...     ...
# 9995     53 Reviews , 54 Followers    6/5/2016 0:08         0     NaN
# 9996      2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
# 9997    65 Reviews , 423 Followers   6/3/2016 10:37         3     NaN
# 9998    13 Reviews , 144 Followers  5/31/2016 17:22         0     NaN
# 9999  472 Reviews , 1302 Followers  5/31/2016 16:41         6     NaN
#
# [9964 rows x 8 columns]

# %%
#                 Basic String Manipulation: (All) 
# 1. Convert the Reviewer column values to lowercase. 
df["Reviewer"].str.lower()
# Out:
# 0          rusha chakraborty
# 1       anusha tirumalaneedi
# 2            ashok shekhawat
# 3             swapnil sarkar
# 4                     dileep
#                 ...
# 9995        abhishek mahajan
# 9996          sharad agrawal
# 9997               ramandeep
# 9998         nayana shanbhag
# 9999        bhargava krishna
# Name: Reviewer, Length: 9964, dtype: object

# %%
# 2. Extract the first 3 characters of the Reviewer column. 
df["Reviewer"].str[:3]
# Out:
# 0       Rus
# 1       Anu
# 2       Ash
# 3       Swa
# 4       Dil
#        ...
# 9995    Abh
# 9996    Sha
# 9997    Ram
# 9998    Nay
# 9999    Bha
# Name: Reviewer, Length: 9964, dtype: object

# %%
# 3. Split the Reviewer column into two columns: First_Name and Last_Name. 
dfcopy = df.copy()
dfcopy[["First_Name","Last_Name"]]=dfcopy["Reviewer"].str.split(" ",n=1,expand = True)
dfcopy["Last_Name"] = dfcopy["Last_Name"].fillna("")
dfcopy = dfcopy.drop(columns=["Reviewer"])
dfcopy
# Out:
#             Restaurant                                             Review  \
# 0      Beyond Flavours  The ambience was good, food was quite good . h...
# 1      Beyond Flavours  Ambience is too good for a pleasant evening. S...
# 2      Beyond Flavours  A must try.. great food great ambience. Thnx f...
# 3      Beyond Flavours  Soumen das and Arun was a great guy. Only beca...
# 4      Beyond Flavours  Food is good.we ordered Kodi drumsticks and ba...
# ...                ...                                                ...
# 9995  Chinese Pavilion  Madhumathi Mahajan Well to start with nice cou...
# 9996  Chinese Pavilion  This place has never disappointed us.. The foo...
# 9997  Chinese Pavilion  Bad rating is mainly because of "Chicken Bone ...
# 9998  Chinese Pavilion  I personally love and prefer Chinese Food. Had...
# 9999  Chinese Pavilion  Checked in here to try some delicious chinese ...
#
#       Rating                      Metadata             Time  Pictures    7514  \
# 0        5.0        1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1        5.0       3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2        5.0       2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3        5.0         1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4        5.0       3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...      ...                           ...              ...       ...     ...
# 9995     3.0     53 Reviews , 54 Followers    6/5/2016 0:08         0     NaN
# 9996     4.5      2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
# 9997     1.5    65 Reviews , 423 Followers   6/3/2016 10:37         3     NaN
# 9998     4.0    13 Reviews , 144 Followers  5/31/2016 17:22         0     NaN
# 9999     3.5  472 Reviews , 1302 Followers  5/31/2016 16:41         6     NaN
#
#      First_Name      Last_Name
# 0         Rusha    Chakraborty
# 1        Anusha  Tirumalaneedi
# 2         Ashok      Shekhawat
# 3       Swapnil         Sarkar
# 4        Dileep
# ...         ...            ...
# 9995   Abhishek        Mahajan
# 9996     Sharad        Agrawal
# 9997  Ramandeep
# 9998     Nayana       Shanbhag
# 9999   Bhargava        Krishna
#
# [9964 rows x 9 columns]

# %%
# 4. Concatenate the First_Name and Last_Name columns into a new column Reviewer. 
dfcopy["Reviewer"] = dfcopy["First_Name"]+ " "+ dfcopy["Last_Name"] 
dfcopy = dfcopy.drop(columns=['First_Name','Last_Name'])
dfcopy
# Out:
#             Restaurant                                             Review  \
# 0      Beyond Flavours  The ambience was good, food was quite good . h...
# 1      Beyond Flavours  Ambience is too good for a pleasant evening. S...
# 2      Beyond Flavours  A must try.. great food great ambience. Thnx f...
# 3      Beyond Flavours  Soumen das and Arun was a great guy. Only beca...
# 4      Beyond Flavours  Food is good.we ordered Kodi drumsticks and ba...
# ...                ...                                                ...
# 9995  Chinese Pavilion  Madhumathi Mahajan Well to start with nice cou...
# 9996  Chinese Pavilion  This place has never disappointed us.. The foo...
# 9997  Chinese Pavilion  Bad rating is mainly because of "Chicken Bone ...
# 9998  Chinese Pavilion  I personally love and prefer Chinese Food. Had...
# 9999  Chinese Pavilion  Checked in here to try some delicious chinese ...
#
#       Rating                      Metadata             Time  Pictures    7514  \
# 0        5.0        1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1        5.0       3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2        5.0       2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3        5.0         1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4        5.0       3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...      ...                           ...              ...       ...     ...
# 9995     3.0     53 Reviews , 54 Followers    6/5/2016 0:08         0     NaN
# 9996     4.5      2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
# 9997     1.5    65 Reviews , 423 Followers   6/3/2016 10:37         3     NaN
# 9998     4.0    13 Reviews , 144 Followers  5/31/2016 17:22         0     NaN
# 9999     3.5  472 Reviews , 1302 Followers  5/31/2016 16:41         6     NaN
#
#                   Reviewer
# 0        Rusha Chakraborty
# 1     Anusha Tirumalaneedi
# 2          Ashok Shekhawat
# 3           Swapnil Sarkar
# 4                  Dileep
# ...                    ...
# 9995      Abhishek Mahajan
# 9996        Sharad Agrawal
# 9997            Ramandeep
# 9998       Nayana Shanbhag
# 9999      Bhargava Krishna
#
# [9964 rows x 8 columns]

# %%
# 5. Replace all spaces in the Reviewer column with underscores. 
df["Reviewer"].str.replace(" ", "_")
# Out:
# 0          Rusha_Chakraborty
# 1       Anusha_Tirumalaneedi
# 2            Ashok_Shekhawat
# 3             Swapnil_Sarkar
# 4                     Dileep
#                 ...
# 9995        Abhishek_Mahajan
# 9996          Sharad_Agrawal
# 9997               Ramandeep
# 9998         Nayana_Shanbhag
# 9999        Bhargava_Krishna
# Name: Reviewer, Length: 9964, dtype: object

# %%
#                 iloc - Integer-location based indexing: (Any 5) 
# 1. Select the first row of the dataset using iloc. 
df.iloc[:1]
# Out:
#         Restaurant           Reviewer  \
# 0  Beyond Flavours  Rusha Chakraborty
#
#                                               Review  Rating  \
# 0  The ambience was good, food was quite good . h...     5.0
#
#                  Metadata             Time  Pictures    7514
# 0  1 Review , 2 Followers  5/25/2019 15:54         0  2447.0

# %%
# 2. Select the last 3 rows of the dataset using iloc. 
df.iloc[-3:]
# Out:
#             Restaurant          Reviewer  \
# 9997  Chinese Pavilion         Ramandeep
# 9998  Chinese Pavilion   Nayana Shanbhag
# 9999  Chinese Pavilion  Bhargava Krishna
#
#                                                  Review  Rating  \
# 9997  Bad rating is mainly because of "Chicken Bone ...     1.5
# 9998  I personally love and prefer Chinese Food. Had...     4.0
# 9999  Checked in here to try some delicious chinese ...     3.5
#
#                           Metadata             Time  Pictures  7514
# 9997    65 Reviews , 423 Followers   6/3/2016 10:37         3   NaN
# 9998    13 Reviews , 144 Followers  5/31/2016 17:22         0   NaN
# 9999  472 Reviews , 1302 Followers  5/31/2016 16:41         6   NaN

# %%
# 3. Select the first 5 rows and the first 3 columns using iloc. 
df.iloc[:5,:3]
# Out:
#         Restaurant              Reviewer  \
# 0  Beyond Flavours     Rusha Chakraborty
# 1  Beyond Flavours  Anusha Tirumalaneedi
# 2  Beyond Flavours       Ashok Shekhawat
# 3  Beyond Flavours        Swapnil Sarkar
# 4  Beyond Flavours                Dileep
#
#                                               Review
# 0  The ambience was good, food was quite good . h...
# 1  Ambience is too good for a pleasant evening. S...
# 2  A must try.. great food great ambience. Thnx f...
# 3  Soumen das and Arun was a great guy. Only beca...
# 4  Food is good.we ordered Kodi drumsticks and ba...

# %%
# 4. Select all rows of the dataset but only the 2nd and 3rd columns using iloc. 
df.iloc[:,[1,2]]
# Out:
#                   Reviewer                                             Review
# 0        Rusha Chakraborty  The ambience was good, food was quite good . h...
# 1     Anusha Tirumalaneedi  Ambience is too good for a pleasant evening. S...
# 2          Ashok Shekhawat  A must try.. great food great ambience. Thnx f...
# 3           Swapnil Sarkar  Soumen das and Arun was a great guy. Only beca...
# 4                   Dileep  Food is good.we ordered Kodi drumsticks and ba...
# ...                    ...                                                ...
# 9995      Abhishek Mahajan  Madhumathi Mahajan Well to start with nice cou...
# 9996        Sharad Agrawal  This place has never disappointed us.. The foo...
# 9997             Ramandeep  Bad rating is mainly because of "Chicken Bone ...
# 9998       Nayana Shanbhag  I personally love and prefer Chinese Food. Had...
# 9999      Bhargava Krishna  Checked in here to try some delicious chinese ...
#
# [9964 rows x 2 columns]

# %%
# 5. Select the value at the 4th row and 2nd column using iloc. 
df.iloc[3,1]
# Out:
# 'Swapnil Sarkar'

# %%
# 6. Use iloc to select rows 2 to 5 and columns 1 to 4. 
df.iloc[1:5,:4]
# Out:
#         Restaurant              Reviewer  \
# 1  Beyond Flavours  Anusha Tirumalaneedi
# 2  Beyond Flavours       Ashok Shekhawat
# 3  Beyond Flavours        Swapnil Sarkar
# 4  Beyond Flavours                Dileep
#
#                                               Review  Rating
# 1  Ambience is too good for a pleasant evening. S...     5.0
# 2  A must try.. great food great ambience. Thnx f...     5.0
# 3  Soumen das and Arun was a great guy. Only beca...     5.0
# 4  Food is good.we ordered Kodi drumsticks and ba...     5.0

# %%
#                 loc - Label-based indexing: (Any 5) 
# 1. Select the row where the Reviewer is "Dileep" using loc. 
df.loc[df["Reviewer"]=="Dileep"]
# Out:
#                           Restaurant Reviewer  \
# 4                    Beyond Flavours   Dileep
# 329   Shah Ghouse Hotel & Restaurant   Dileep
# 4801                  Udipi's Upahar   Dileep
#
#                                                  Review  Rating  \
# 4     Food is good.we ordered Kodi drumsticks and ba...     5.0
# 329   Perfect place to order for mutton Biryani and ...     4.0
# 4801  Good south Indian breakfast items .. u can try...     4.0
#
#                      Metadata             Time  Pictures  7514
# 4     3 Reviews , 2 Followers  5/24/2019 21:37         0   NaN
# 329     1 Review , 1 Follower   5/3/2019 23:31         0   NaN
# 4801   3 Reviews , 1 Follower   5/4/2019 19:03         0   NaN

# %%
# 2. Select rows where the Rating is greater than 4.5 using loc. 
df.loc[df["Rating"]>4.5]
# Out:
#             Restaurant                     Reviewer  \
# 0      Beyond Flavours            Rusha Chakraborty
# 1      Beyond Flavours         Anusha Tirumalaneedi
# 2      Beyond Flavours              Ashok Shekhawat
# 3      Beyond Flavours               Swapnil Sarkar
# 4      Beyond Flavours                       Dileep
# ...                ...                          ...
# 9983  Chinese Pavilion  @FuloriBinaChutneyKaiseBani
# 9990  Chinese Pavilion                 Akram Ul Haq
# 9991  Chinese Pavilion      Krishna Teja Ratnakaram
# 9992  Chinese Pavilion                   Sujay Garg
# 9993  Chinese Pavilion                  Richard Rao
#
#                                                  Review  Rating  \
# 0     The ambience was good, food was quite good . h...     5.0
# 1     Ambience is too good for a pleasant evening. S...     5.0
# 2     A must try.. great food great ambience. Thnx f...     5.0
# 3     Soumen das and Arun was a great guy. Only beca...     5.0
# 4     Food is good.we ordered Kodi drumsticks and ba...     5.0
# ...                                                 ...     ...
# 9983  What a delightful place. Food was the star her...     5.0
# 9990  Amazing food ! I always go here when I want Ch...     5.0
# 9991  I was never a fan of Chinese food until I visi...     5.0
# 9992  I visited this restaurant with friends and was...     5.0
# 9993  Im going to cut to the chase, The food is exce...     5.0
#
#                         Metadata             Time  Pictures    7514
# 0         1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1        3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2        2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3          1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4        3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...                          ...              ...       ...     ...
# 9983  86 Reviews , 244 Followers   9/5/2016 16:43         0     NaN
# 9990   3 Reviews , 128 Followers  6/16/2016 13:53         0     NaN
# 9991    9 Reviews , 54 Followers   6/15/2016 0:50         0     NaN
# 9992      4 Reviews , 1 Follower   6/15/2016 0:04         0     NaN
# 9993    3 Reviews , 74 Followers  6/14/2016 18:35         0     NaN
#
# [3832 rows x 8 columns]

# %%
# 3. Select the City column for rows where Rating is between 3 and 4 using loc. 
df.loc[(df["Rating"]>3) & (df["Rating"]<4)]
# Out:
#                                    Restaurant  \
# 975                               Cream Stone
# 5940                                KS Bakers
# 5946                                KS Bakers
# 5968                                KS Bakers
# 5988                                KS Bakers
# 5989                                KS Bakers
# 5990                                KS Bakers
# 5995                                KS Bakers
# 5997                                KS Bakers
# 6574  Komatose - Holiday Inn Express & Suites
# 7259                                  Labonel
# 7260                                  Labonel
# 7268                                  Labonel
# 7275                                  Labonel
# 7278                                  Labonel
# 7279                                  Labonel
# 7291                                  Labonel
# 7298                                  Labonel
# 8184                                 Delhi-39
# 8288                       Al Saba Restaurant
# 8291                       Al Saba Restaurant
# 8295                       Al Saba Restaurant
# 8299                       Al Saba Restaurant
# 8485                                  T Grill
# 8489                                  T Grill
# 8498                                  T Grill
# 9180  Cascade - Radisson Hyderabad Hitec City
# 9181  Cascade - Radisson Hyderabad Hitec City
# 9184  Cascade - Radisson Hyderabad Hitec City
# 9192  Cascade - Radisson Hyderabad Hitec City
# 9193  Cascade - Radisson Hyderabad Hitec City
# 9281     Collage - Hyatt Hyderabad Gachibowli
# 9472                           Dunkin' Donuts
# 9476                           Dunkin' Donuts
# 9488                           Dunkin' Donuts
# 9492                           Dunkin' Donuts
# 9493                           Dunkin' Donuts
# 9496                           Dunkin' Donuts
# 9498                           Dunkin' Donuts
# 9945                         Chinese Pavilion
# 9952                         Chinese Pavilion
# 9957                         Chinese Pavilion
# 9970                         Chinese Pavilion
# 9974                         Chinese Pavilion
# 9985                         Chinese Pavilion
# 9987                         Chinese Pavilion
# 9999                         Chinese Pavilion
#
#                               Reviewer  \
# 975                     Yashwant Darsi
# 5940                       Parijat Ray
# 5946                   Aanshul Sadaria
# 5968                        Jameel Ali
# 5988                             Raghu
# 5989                     Nikita Kumari
# 5990                      Kumar Anshul
# 5995                     Sonofepicurus
# 5997                Siddharth Jaligama
# 6574                     Rajat Goel ✳️
# 7259                   Yattapu Srinija
# 7260         Ashisha, The 'Bon Viveur'
# 7268                        D.gurazada
# 7275                Christopher Mathew
# 7278              Sreejith Sreekumaran
# 7279                       Ankita Shah
# 7291                    Sprutika Battu
# 7298                          Eman Ali
# 8184                      Surbhi Verma
# 8288                        Foodtrakar
# 8291                    Ranjith Chinni
# 8295                   Sanket Kulkarni
# 8299             Raveendra Medarametla
# 8485                   Meher Chaitanya
# 8489               Krishnamraju Maladi
# 8498                  Chandan Mashetty
# 9180                    Vishnu Vardhan
# 9181                 Shrishail Deshnur
# 9184                     Manikanda Pai
# 9192                         Preethi P
# 9193      Harsh Baldev (Feed Me & Co.)
# 9281                     Akanksha Jain
# 9472                   Ketaki Agharkar
# 9476                       Rohit Reddy
# 9488      Shoeb Patel (Food Assassin)™
# 9492                      Souvik Patra
# 9493              Manoj Kumar Chowdary
# 9496                     Foodie Cookie
# 9498           Revathy Mahe Periyasamy
# 9945                          Mujeeb M
# 9952                          Mujjuiz1
# 9957                               Deb
# 9970  Raghav Peddi 'The Food Shaukeen'
# 9974                 What's In A Name?
# 9985                      Gopi Krishna
# 9987                          Deba Das
# 9999                  Bhargava Krishna
#
#                                                  Review  Rating  \
# 975   It's too crowded with delivery executives all ...     3.5
# 5940  Nice pocket friendly place. Burgers and sandwi...     3.5
# 5946  Well, all the time I have ordered here it has ...     3.5
# 5968  chocolate truffle is great here!\nFerrerro roc...     3.5
# 5988  KS bakers , known for its food in bakery items...     3.5
# 5989  Ordered chicken and cheese burger and egg puff...     3.5
# 5990  The burger was just decent but complete value ...     3.5
# 5995  It's a good option but the bread they use for ...     3.5
# 5997  Neat and clean ambiance. Small place but it's ...     3.5
# 6574  Komatose on a Sunday night is the perfect plac...     3.5
# 7259  I have ordered carrot cake with cream cheese f...     3.5
# 7260  Had their classic brownie cake which is served...     3.5
# 7268  They make the Best red velvet cake and cup cak...     3.5
# 7275  One of the premium bakers in gachibowli, most ...     3.5
# 7278  labonel has become a hotspot for premium and r...     3.5
# 7279  Definitely a very popular bakery in hyderabad ...     3.5
# 7291  These brownies literally melt in your mouth!\n...     3.5
# 7298  I went to Labonel a long time ago.\n\nThere ha...     3.5
# 8184  If you are looking for some good north Indian ...     3.5
# 8288  Ordered Al-saba special mutton biryani. The qu...     3.5
# 8291  Another place fo delicious Hyderabadi rum biry...     3.5
# 8295  Great quantity and good platting for my starte...     3.5
# 8299  You might have heard about the really good bir...     3.5
# 8485  A good place for some Telangana taste! The gri...     3.5
# 8489  Great ambience and hut style .....Ragi mudda c...     3.5
# 8498  Been here with my team mates..chicken kebab, c...     3.5
# 9180  Good ambience and obvious reasons that it is 4...     3.5
# 9181  Stayed at Radisson Hyderabad and got to experi...     3.5
# 9184  We went to Cascade for Birthday dinner and opt...     3.5
# 9192  The place is amazing. The food is of huge vari...     3.5
# 9193  #ByManagementInvite #feedmehyderabad\n\nRadiss...     3.5
# 9281  Lunch Buffet: 3/5\nFood tasted good. Desserts ...     3.5
# 9472  Some bad donuts and some surprisingly good bur...     3.5
# 9476  Been to this place a few times before. Known f...     3.5
# 9488  Taste is Awesome!!!\nPrice is affordable and O...     3.5
# 9492  Simple and sweet outlet. I liked the episode o...     3.5
# 9493  I can't say the donuts are too tasty.if you ar...     3.5
# 9496  This has been my favourite donut place here. I...     3.5
# 9498  Ate ma first donuts here 😋They we're just amaz...     3.5
# 9945  Food: Chinese with a touch of Indian masalas. ...     3.5
# 9952  Your quest for authentic Indo Chinese food tha...     3.5
# 9957  Lust for authentic Chinese food takes me to th...     3.5
# 9970  #Delayedpost (date of visit Jan 10)\n\n#FoodSh...     3.5
# 9974  Went there with friends.The staff was polite.H...     3.5
# 9985  Searched for Chinese cuisine nearby and I foun...     3.5
# 9987  Initially thought of going to Wonton (Gachibow...     3.5
# 9999  Checked in here to try some delicious chinese ...     3.5
#
#                           Metadata              Time  Pictures  7514
# 975      14 Reviews , 83 Followers  11/13/2018 20:09         0   NaN
# 5940   146 Reviews , 333 Followers   3/12/2018 18:03         0   NaN
# 5946     26 Reviews , 42 Followers    1/2/2018 22:07         0   NaN
# 5968     21 Reviews , 13 Followers  12/10/2017 22:48         0   NaN
# 5988  443 Reviews , 1016 Followers   8/21/2017 23:21         6   NaN
# 5989   140 Reviews , 363 Followers   8/18/2017 14:05         4   NaN
# 5990   169 Reviews , 680 Followers    8/14/2017 2:09         2   NaN
# 5995   140 Reviews , 931 Followers    7/8/2017 16:28         0   NaN
# 5997    45 Reviews , 253 Followers     7/2/2017 8:21         0   NaN
# 6574  148 Reviews , 3383 Followers   6/18/2018 14:26        12   NaN
# 7259        4 Reviews , 1 Follower    7/17/2017 0:31         0   NaN
# 7260   110 Reviews , 227 Followers    7/16/2017 8:51         1   NaN
# 7268     15 Reviews , 10 Followers    4/6/2017 10:46         0   NaN
# 7275    51 Reviews , 200 Followers    2/27/2017 0:42         2   NaN
# 7278   207 Reviews , 299 Followers   2/13/2017 14:41         1   NaN
# 7279    73 Reviews , 951 Followers   2/12/2017 21:49         0   NaN
# 7291    24 Reviews , 152 Followers  11/14/2016 21:25         0   NaN
# 7298        7 Reviews , 1 Follower   10/13/2016 1:04         0   NaN
# 8184       4 Reviews , 3 Followers    5/1/2018 21:33         0   NaN
# 8288    57 Reviews , 150 Followers     3/1/2018 9:57         0   NaN
# 8291     47 Reviews , 98 Followers  11/24/2017 20:58         0   NaN
# 8295       2 Reviews , 3 Followers   10/13/2017 1:35         0   NaN
# 8299    66 Reviews , 639 Followers   8/26/2017 22:03         1   NaN
# 8485    29 Reviews , 177 Followers  12/16/2017 20:19         0   NaN
# 8489      5 Reviews , 43 Followers  11/27/2017 22:30         0   NaN
# 8498     38 Reviews , 14 Followers   8/17/2017 16:56         0   NaN
# 9180    33 Reviews , 264 Followers  12/14/2017 13:04         0   NaN
# 9181  414 Reviews , 1047 Followers   12/1/2017 13:57        10   NaN
# 9184     24 Reviews , 22 Followers   10/23/2017 6:06         0   NaN
# 9192     32 Reviews , 20 Followers   8/27/2017 23:25         0   NaN
# 9193  279 Reviews , 1948 Followers   8/24/2017 14:59         6   NaN
# 9281    73 Reviews , 411 Followers    1/16/2018 0:26         2   NaN
# 9472     20 Reviews , 60 Followers   1/16/2018 20:29         4   NaN
# 9476   99 Reviews , 2972 Followers    12/7/2017 0:25         0   NaN
# 9488   236 Reviews , 606 Followers    9/6/2017 20:24         0   NaN
# 9492   337 Reviews , 832 Followers   8/14/2017 13:23         7   NaN
# 9493      7 Reviews , 32 Followers   8/13/2017 23:25         2   NaN
# 9496   247 Reviews , 316 Followers   8/12/2017 10:46         2   NaN
# 9498     12 Reviews , 95 Followers    8/1/2017 12:30         6   NaN
# 9945  123 Reviews , 1661 Followers   12/1/2017 23:05         6   NaN
# 9952     22 Reviews , 58 Followers    8/11/2017 0:05         3   NaN
# 9957    98 Reviews , 116 Followers    6/19/2017 6:40         6   NaN
# 9970  310 Reviews , 2001 Followers    1/22/2017 0:47        10   NaN
# 9974   251 Reviews , 576 Followers   12/2/2016 10:57         0   NaN
# 9985   138 Reviews , 540 Followers   8/14/2016 22:37        20   NaN
# 9987    31 Reviews , 101 Followers   7/24/2016 16:44         3   NaN
# 9999  472 Reviews , 1302 Followers   5/31/2016 16:41         6   NaN

# %%
# 4. Select all rows and columns where Reviewer is "Sujay Garg" using loc. 
df.loc[df["Reviewer"]=="Sujay Garg"]
# Out:
#             Restaurant    Reviewer  \
# 9992  Chinese Pavilion  Sujay Garg
#
#                                                  Review  Rating  \
# 9992  I visited this restaurant with friends and was...     5.0
#
#                     Metadata            Time  Pictures  7514
# 9992  4 Reviews , 1 Follower  6/15/2016 0:04         0   NaN

# %%
# 5. Select multiple columns (Reviewer, Rating) for a specific row with loc. 
df.loc[:0,["Reviewer","Rating"]]
# Out:
#             Reviewer  Rating
# 0  Rusha Chakraborty     5.0

# %%
# 6. Use loc to select the row where Rating is greater than 4.5 and the Restaurant is "KS Bakers".
df.loc[(df["Rating"]>4.5)&(df["Restaurant"]=="KS Bakers")]
# Out:
#      Restaurant                   Reviewer  \
# 5901  KS Bakers                     Sravya
# 5904  KS Bakers          Saraswati Jeswani
# 5907  KS Bakers                      Nillu
# 5910  KS Bakers            Khushboo Pandey
# 5911  KS Bakers                  Satish Ch
# 5912  KS Bakers                Sai Krishna
# 5917  KS Bakers                      Kiran
# 5920  KS Bakers              LAVANYA REDDY
# 5923  KS Bakers          Sayantan Banerjee
# 5926  KS Bakers              Kishan Mallik
# 5927  KS Bakers          Nancharla Lavanya
# 5933  KS Bakers            Prashanth Lucky
# 5934  KS Bakers                     Naresh
# 5935  KS Bakers             Sudha Sudhakar
# 5943  KS Bakers              Sandeep Kumar
# 5945  KS Bakers                   Srinivas
# 5947  KS Bakers               Aabhi Chachu
# 5948  KS Bakers                 Ramu Reddy
# 5950  KS Bakers               Ramesh Mella
# 5952  KS Bakers               Naveen Reddy
# 5953  KS Bakers  Krishna Crazyboy Crazyboy
# 5954  KS Bakers             Pavanmodel7772
# 5955  KS Bakers              Pavani Smiley
# 5956  KS Bakers         Syedmajidali Majid
# 5960  KS Bakers             Krishna Siddhu
# 5961  KS Bakers               Rockey Yo Yo
# 5962  KS Bakers            Krishna Krishna
# 5963  KS Bakers   Naveen Karuturi Chowdary
# 5965  KS Bakers               Nagadurgasai
# 5966  KS Bakers                 Sunil Mass
# 5969  KS Bakers          Mehuli Nag Biswas
# 5970  KS Bakers               Mukul Mittal
# 5973  KS Bakers                 Hasan Raza
# 5974  KS Bakers               Sree Vatsava
# 5975  KS Bakers             Matta Saikumar
# 5977  KS Bakers            Shravanthi Srav
# 5978  KS Bakers          Radhika Nancharla
# 5979  KS Bakers              Adurga Prasad
# 5980  KS Bakers             Balraj Kummari
# 5981  KS Bakers                Suhail Hadi
#
#                                                  Review  Rating  \
# 5901  very good and had ultimate taste of the cake. ...     5.0
# 5904  Awsome food at very reasonable price. Must try...     5.0
# 5907  I have visited several times for cake . Here y...     5.0
# 5910  Quallity- 5/5: They have a special taste, a sp...     5.0
# 5911  ordered veg hot mexican pizza, Blueberry pastr...     5.0
# 5912  Ordered paneer tikka pizza through swiggy...wh...     5.0
# 5917  KS Bakers has several branches in Hyderabad an...     5.0
# 5920  Loved chicken burger & Chicken tikka burger. A...     5.0
# 5923  One of the best Baker shops in the city. I tas...     5.0
# 5926  I wouldn't mind eating shorteats from KS Baker...     5.0
# 5927  Came with family here and went to first floor ...     5.0
# 5933  Hi . I got cake from here which called some jo...     5.0
# 5934  Visited with my gang here and tasted chicken f...     5.0
# 5935  Wonderful place to have burgers, pizzas, pastr...     5.0
# 5943  I have ordered a cake suggested by Mr.Rajesh f...     5.0
# 5945  Had a chicken mix pizza here today. Very tasty...     5.0
# 5947  Today morning me and my friends and had some p...     5.0
# 5948  Visited here few times .today is very crowdy. ...     5.0
# 5950  We had dark chocolate and German black forest ...     5.0
# 5952  I have taken a pineapple marble cake here. It'...     5.0
# 5953  Bought an almond cake from here as some salesm...     5.0
# 5954  Got a Italian chocolate cake for Christmas cel...     5.0
# 5955  Very good items to have with friends and famil...     5.0
# 5956  Am big fan of KS as we are regular customers ....     5.0
# 5960  Had a chicken burger here. Great taste and les...     5.0
# 5961  Great prices and great prices. I have bought f...     5.0
# 5962  Famous bakery which i liked very much ...every...     5.0
# 5963  Loved their varieties...red velvet cream chees...     5.0
# 5965  Me and my friends loved ks varities.. We daily...     5.0
# 5966  Visited several times really good place to go ...     5.0
# 5969  Really loved the place and the varieties they ...     5.0
# 5970  Thanks KS Baker's for helping and delivering t...     5.0
# 5973  Best place for birthday parties and for pizzaa...     5.0
# 5974  Tried both vegetarian and non vegetarian pizza...     5.0
# 5975  I loved everything here.. Tasted pastries I lo...     5.0
# 5977  I have ordered box packing from here .. combin...     5.0
# 5978  Its in prime location of gachibowli ..I went s...     5.0
# 5979  Ambiance is very good . People are very respon...     5.0
# 5980  Awesome taste at affordable prices..litchi pas...     5.0
# 5981  Ks bakers budget friendly anda taste is fantan...     5.0
#
#                          Metadata              Time  Pictures  7514
# 5901       8 Reviews , 1 Follower   5/13/2019 20:01         3   NaN
# 5904       1 Review , 4 Followers    3/15/2019 8:14         0   NaN
# 5907     17 Reviews , 9 Followers   2/10/2019 23:59         0   NaN
# 5910    59 Reviews , 42 Followers    1/2/2019 22:41         2   NaN
# 5911      9 Reviews , 7 Followers  12/29/2018 23:59         3   NaN
# 5912                     1 Review  12/25/2018 13:16         0   NaN
# 5917      8 Reviews , 3 Followers   10/9/2018 20:10         0   NaN
# 5920                     1 Review    9/8/2018 16:41         0   NaN
# 5923    13 Reviews , 42 Followers   7/20/2018 22:48         0   NaN
# 5926  222 Reviews , 665 Followers   7/16/2018 21:53         0   NaN
# 5927        1 Review , 1 Follower   7/15/2018 20:35         0   NaN
# 5933        1 Review , 1 Follower   6/10/2018 19:25         0   NaN
# 5934        1 Review , 1 Follower   6/10/2018 19:20         1   NaN
# 5935        1 Review , 1 Follower    6/9/2018 19:24         0   NaN
# 5943      1 Review , 10 Followers    2/1/2018 23:41         0   NaN
# 5945       2 Reviews , 1 Follower   1/11/2018 19:47         0   NaN
# 5947       1 Review , 2 Followers  12/30/2017 17:50         0   NaN
# 5948                     1 Review  12/29/2017 21:08         0   NaN
# 5950        1 Review , 1 Follower  12/27/2017 18:11         1   NaN
# 5952                     1 Review  12/27/2017 15:11         0   NaN
# 5953        1 Review , 1 Follower  12/26/2017 19:54         1   NaN
# 5954        1 Review , 1 Follower  12/26/2017 13:55         0   NaN
# 5955      1 Review , 26 Followers  12/25/2017 19:14         0   NaN
# 5956        1 Review , 1 Follower  12/25/2017 17:25         0   NaN
# 5960     2 Reviews , 16 Followers  12/25/2017 12:58         0   NaN
# 5961        1 Review , 1 Follower  12/24/2017 20:07         0   NaN
# 5962        1 Review , 1 Follower  12/24/2017 18:45         0   NaN
# 5963        1 Review , 1 Follower  12/24/2017 18:07         1   NaN
# 5965                     1 Review  12/14/2017 19:42         0   NaN
# 5966      1 Review , 32 Followers  12/13/2017 18:35         0   NaN
# 5969   72 Reviews , 225 Followers   12/10/2017 1:15         0   NaN
# 5970     4 Reviews , 11 Followers   12/6/2017 18:26         0   NaN
# 5973       1 Review , 8 Followers  11/25/2017 19:42         3   NaN
# 5974      4 Reviews , 2 Followers  11/25/2017 19:40         0   NaN
# 5975       1 Review , 2 Followers  11/23/2017 19:59         1   NaN
# 5977        1 Review , 1 Follower  11/21/2017 21:19         0   NaN
# 5978       1 Review , 2 Followers  11/21/2017 20:56         0   NaN
# 5979       1 Review , 2 Followers  11/21/2017 12:33         0   NaN
# 5980        1 Review , 1 Follower  11/20/2017 18:10         0   NaN
# 5981       1 Review , 2 Followers  11/20/2017 18:07         0   NaN

# %%
#                 replace - Replacing values in a DataFrame: (Any 5) 
# 1. Replace all occurrences of the value "Dileep" with "Nitin" in the Reviewer column. 
df["Reviewer"].replace("Dileep","Nitin")
# Out:
# 0          Rusha Chakraborty
# 1       Anusha Tirumalaneedi
# 2            Ashok Shekhawat
# 3             Swapnil Sarkar
# 4                      Nitin
#                 ...
# 9995        Abhishek Mahajan
# 9996          Sharad Agrawal
# 9997               Ramandeep
# 9998         Nayana Shanbhag
# 9999        Bhargava Krishna
# Name: Reviewer, Length: 9964, dtype: object

# %%
# 2. Replace the value 0 with NaN in a specific numerical column. 
df["Pictures"].replace(0, np.nan)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 9995    NaN
# 9996    NaN
# 9997    3.0
# 9998    NaN
# 9999    6.0
# Name: Pictures, Length: 9964, dtype: float64

# %%
# 3. Replace a value in the entire DataFrame (e.g., replace all 100s with 50s). 
df["Rating"].replace(2.5,2.0)
# Out:
# 0       5.0
# 1       5.0
# 2       5.0
# 3       5.0
# 4       5.0
#        ...
# 9995    3.0
# 9996    4.5
# 9997    1.5
# 9998    4.0
# 9999    3.5
# Name: Rating, Length: 9964, dtype: float64

# %%
# 4. Replace all occurrences of "Male" with 1 and "Female" with 0 in the Gender column. 
df["Restaurant"].replace({"Beyond Flavours":1,"Chinese Pavilion":0})
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Restaurant, Length: 9964, dtype: object

# %%
# 5. Replace multiple values (e.g., replace "High" with "Medium" and "Low" with "Small" in 
# the Priority column). 
df["Reviewer"].replace({"Rusha Chakraborty":"Nitesh","Anusha Tirumalaneedi":"Aman","Dileep":"Priyansh"})
# Out:
# 0                 Nitesh
# 1                   Aman
# 2        Ashok Shekhawat
# 3         Swapnil Sarkar
# 4               Priyansh
#               ...
# 9995    Abhishek Mahajan
# 9996      Sharad Agrawal
# 9997           Ramandeep
# 9998     Nayana Shanbhag
# 9999    Bhargava Krishna
# Name: Reviewer, Length: 9964, dtype: object

# %%
# 6. Replace the value of "NA" in the Rating column with the mean of the column. 
df["Pictures"].replace(np.nan, df["Pictures"].mean())
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    3
# 9998    0
# 9999    6
# Name: Pictures, Length: 9964, dtype: int64

# %%
#    12.         index - Indexing and resetting index: (Any 5) 
# 1. Set a specific column (e.g., Name) as the index of the DataFrame. 
df.set_index("Restaurant")
# Out:
#                               Reviewer  \
# Restaurant
# Beyond Flavours      Rusha Chakraborty
# Beyond Flavours   Anusha Tirumalaneedi
# Beyond Flavours        Ashok Shekhawat
# Beyond Flavours         Swapnil Sarkar
# Beyond Flavours                 Dileep
# ...                                ...
# Chinese Pavilion      Abhishek Mahajan
# Chinese Pavilion        Sharad Agrawal
# Chinese Pavilion             Ramandeep
# Chinese Pavilion       Nayana Shanbhag
# Chinese Pavilion      Bhargava Krishna
#
#                                                              Review  Rating  \
# Restaurant
# Beyond Flavours   The ambience was good, food was quite good . h...     5.0
# Beyond Flavours   Ambience is too good for a pleasant evening. S...     5.0
# Beyond Flavours   A must try.. great food great ambience. Thnx f...     5.0
# Beyond Flavours   Soumen das and Arun was a great guy. Only beca...     5.0
# Beyond Flavours   Food is good.we ordered Kodi drumsticks and ba...     5.0
# ...                                                             ...     ...
# Chinese Pavilion  Madhumathi Mahajan Well to start with nice cou...     3.0
# Chinese Pavilion  This place has never disappointed us.. The foo...     4.5
# Chinese Pavilion  Bad rating is mainly because of "Chicken Bone ...     1.5
# Chinese Pavilion  I personally love and prefer Chinese Food. Had...     4.0
# Chinese Pavilion  Checked in here to try some delicious chinese ...     3.5
#
#                                       Metadata             Time  Pictures  \
# Restaurant
# Beyond Flavours         1 Review , 2 Followers  5/25/2019 15:54         0
# Beyond Flavours        3 Reviews , 2 Followers  5/25/2019 14:20         0
# Beyond Flavours        2 Reviews , 3 Followers  5/24/2019 22:54         0
# Beyond Flavours          1 Review , 1 Follower  5/24/2019 22:11         0
# Beyond Flavours        3 Reviews , 2 Followers  5/24/2019 21:37         0
# ...                                        ...              ...       ...
# Chinese Pavilion     53 Reviews , 54 Followers    6/5/2016 0:08         0
# Chinese Pavilion      2 Reviews , 53 Followers   6/4/2016 22:01         0
# Chinese Pavilion    65 Reviews , 423 Followers   6/3/2016 10:37         3
# Chinese Pavilion    13 Reviews , 144 Followers  5/31/2016 17:22         0
# Chinese Pavilion  472 Reviews , 1302 Followers  5/31/2016 16:41         6
#
#                     7514
# Restaurant
# Beyond Flavours   2447.0
# Beyond Flavours      NaN
# Beyond Flavours      NaN
# Beyond Flavours      NaN
# Beyond Flavours      NaN
# ...                  ...
# Chinese Pavilion     NaN
# Chinese Pavilion     NaN
# Chinese Pavilion     NaN
# Chinese Pavilion     NaN
# Chinese Pavilion     NaN
#
# [9964 rows x 7 columns]

# %%
# 2. Reset the index of the DataFrame after setting a new column as the index. 
df.reset_index()
# Out:
#       index        Restaurant              Reviewer  \
# 0         0   Beyond Flavours     Rusha Chakraborty
# 1         1   Beyond Flavours  Anusha Tirumalaneedi
# 2         2   Beyond Flavours       Ashok Shekhawat
# 3         3   Beyond Flavours        Swapnil Sarkar
# 4         4   Beyond Flavours                Dileep
# ...     ...               ...                   ...
# 9959   9995  Chinese Pavilion      Abhishek Mahajan
# 9960   9996  Chinese Pavilion        Sharad Agrawal
# 9961   9997  Chinese Pavilion             Ramandeep
# 9962   9998  Chinese Pavilion       Nayana Shanbhag
# 9963   9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review  Rating  \
# 0     The ambience was good, food was quite good . h...     5.0
# 1     Ambience is too good for a pleasant evening. S...     5.0
# 2     A must try.. great food great ambience. Thnx f...     5.0
# 3     Soumen das and Arun was a great guy. Only beca...     5.0
# 4     Food is good.we ordered Kodi drumsticks and ba...     5.0
# ...                                                 ...     ...
# 9959  Madhumathi Mahajan Well to start with nice cou...     3.0
# 9960  This place has never disappointed us.. The foo...     4.5
# 9961  Bad rating is mainly because of "Chicken Bone ...     1.5
# 9962  I personally love and prefer Chinese Food. Had...     4.0
# 9963  Checked in here to try some delicious chinese ...     3.5
#
#                           Metadata             Time  Pictures    7514
# 0           1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1          3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2          2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3            1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4          3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...                            ...              ...       ...     ...
# 9959     53 Reviews , 54 Followers    6/5/2016 0:08         0     NaN
# 9960      2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
# 9961    65 Reviews , 423 Followers   6/3/2016 10:37         3     NaN
# 9962    13 Reviews , 144 Followers  5/31/2016 17:22         0     NaN
# 9963  472 Reviews , 1302 Followers  5/31/2016 16:41         6     NaN
#
# [9964 rows x 9 columns]

# %%
# 3. Set a multi-level index using Restaurant and Rating columns. 
dfindex= df.set_index(["Restaurant","Rating"])
dfindex
# Out:
#                                      Reviewer  \
# Restaurant       Rating
# Beyond Flavours  5.0        Rusha Chakraborty
#                  5.0     Anusha Tirumalaneedi
#                  5.0          Ashok Shekhawat
#                  5.0           Swapnil Sarkar
#                  5.0                   Dileep
# ...                                       ...
# Chinese Pavilion 3.0         Abhishek Mahajan
#                  4.5           Sharad Agrawal
#                  1.5                Ramandeep
#                  4.0          Nayana Shanbhag
#                  3.5         Bhargava Krishna
#
#                                                                     Review  \
# Restaurant       Rating
# Beyond Flavours  5.0     The ambience was good, food was quite good . h...
#                  5.0     Ambience is too good for a pleasant evening. S...
#                  5.0     A must try.. great food great ambience. Thnx f...
#                  5.0     Soumen das and Arun was a great guy. Only beca...
#                  5.0     Food is good.we ordered Kodi drumsticks and ba...
# ...                                                                    ...
# Chinese Pavilion 3.0     Madhumathi Mahajan Well to start with nice cou...
#                  4.5     This place has never disappointed us.. The foo...
#                  1.5     Bad rating is mainly because of "Chicken Bone ...
#                  4.0     I personally love and prefer Chinese Food. Had...
#                  3.5     Checked in here to try some delicious chinese ...
#
#                                              Metadata             Time  \
# Restaurant       Rating
# Beyond Flavours  5.0           1 Review , 2 Followers  5/25/2019 15:54
#                  5.0          3 Reviews , 2 Followers  5/25/2019 14:20
#                  5.0          2 Reviews , 3 Followers  5/24/2019 22:54
#                  5.0            1 Review , 1 Follower  5/24/2019 22:11
#                  5.0          3 Reviews , 2 Followers  5/24/2019 21:37
# ...                                               ...              ...
# Chinese Pavilion 3.0        53 Reviews , 54 Followers    6/5/2016 0:08
#                  4.5         2 Reviews , 53 Followers   6/4/2016 22:01
#                  1.5       65 Reviews , 423 Followers   6/3/2016 10:37
#                  4.0       13 Reviews , 144 Followers  5/31/2016 17:22
#                  3.5     472 Reviews , 1302 Followers  5/31/2016 16:41
#
#                          Pictures    7514
# Restaurant       Rating
# Beyond Flavours  5.0            0  2447.0
#                  5.0            0     NaN
#                  5.0            0     NaN
#                  5.0            0     NaN
#                  5.0            0     NaN
# ...                           ...     ...
# Chinese Pavilion 3.0            0     NaN
#                  4.5            0     NaN
#                  1.5            3     NaN
#                  4.0            0     NaN
#                  3.5            6     NaN
#
# [9964 rows x 6 columns]

# %%
# 4. Access a specific row by using the index after setting the index to City. 
dfindex.loc["Beyond Flavours"]
# Out:
#                     Reviewer  \
# Rating
# 5.0        Rusha Chakraborty
# 5.0     Anusha Tirumalaneedi
# 5.0          Ashok Shekhawat
# 5.0           Swapnil Sarkar
# 5.0                   Dileep
# ...                      ...
# 3.0             Gaurav Saini
# 5.0             Kailash Sain
# 5.0             KAILASH SAIN
# 2.0        Yaswanth Chowdary
# 4.0                   Aditya
#
#                                                    Review  \
# Rating
# 5.0     The ambience was good, food was quite good . h...
# 5.0     Ambience is too good for a pleasant evening. S...
# 5.0     A must try.. great food great ambience. Thnx f...
# 5.0     Soumen das and Arun was a great guy. Only beca...
# 5.0     Food is good.we ordered Kodi drumsticks and ba...
# ...                                                   ...
# 3.0     Was there for office lunch outing. Rating woul...
# 5.0     I really enjoyed the follows....\nThe entrance...
# 5.0     I came first time in this restaurant.\nThe ent...
# 2.0     Pathetic and horrible experience\nAmbience and...
# 4.0     Ahmed was serving us. Polite and very cooperat...
#
#                         Metadata             Time  Pictures    7514
# Rating
# 5.0       1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 5.0      3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 5.0      2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 5.0        1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 5.0      3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...                          ...              ...       ...     ...
# 3.0      5 Reviews , 7 Followers   5/4/2019 16:56         0     NaN
# 5.0                     1 Review   5/3/2019 20:10         0     NaN
# 5.0                     1 Review   5/3/2019 20:06         0     NaN
# 2.0     4 Reviews , 56 Followers   5/3/2019 11:40         0     NaN
# 4.0     4 Reviews , 46 Followers   5/2/2019 23:28         1     NaN
#
# [100 rows x 6 columns]

# %%
# 5. Check the index type and whether it’s unique. 
type(dfindex.index)
dfindex.index.is_unique
# Out:
# False

# %%
# 6. Rename the index labels to make them more descriptive (e.g., from numeric to "Row_1", 
# "Row_2").
dfindex.reset_index()
dfindex.index= ["Row_"+ str(i+1) for i in range(len(dfindex))]
dfindex
# Out:
#                       Reviewer  \
# Row_1        Rusha Chakraborty
# Row_2     Anusha Tirumalaneedi
# Row_3          Ashok Shekhawat
# Row_4           Swapnil Sarkar
# Row_5                   Dileep
# ...                        ...
# Row_9960      Abhishek Mahajan
# Row_9961        Sharad Agrawal
# Row_9962             Ramandeep
# Row_9963       Nayana Shanbhag
# Row_9964      Bhargava Krishna
#
#                                                      Review  \
# Row_1     The ambience was good, food was quite good . h...
# Row_2     Ambience is too good for a pleasant evening. S...
# Row_3     A must try.. great food great ambience. Thnx f...
# Row_4     Soumen das and Arun was a great guy. Only beca...
# Row_5     Food is good.we ordered Kodi drumsticks and ba...
# ...                                                     ...
# Row_9960  Madhumathi Mahajan Well to start with nice cou...
# Row_9961  This place has never disappointed us.. The foo...
# Row_9962  Bad rating is mainly because of "Chicken Bone ...
# Row_9963  I personally love and prefer Chinese Food. Had...
# Row_9964  Checked in here to try some delicious chinese ...
#
#                               Metadata             Time  Pictures    7514
# Row_1           1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# Row_2          3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# Row_3          2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# Row_4            1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# Row_5          3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...                                ...              ...       ...     ...
# Row_9960     53 Reviews , 54 Followers    6/5/2016 0:08         0     NaN
# Row_9961      2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
# Row_9962    65 Reviews , 423 Followers   6/3/2016 10:37         3     NaN
# Row_9963    13 Reviews , 144 Followers  5/31/2016 17:22         0     NaN
# Row_9964  472 Reviews , 1302 Followers  5/31/2016 16:41         6     NaN
#
# [9964 rows x 6 columns]

# %%
df
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review  Rating  \
# 0     The ambience was good, food was quite good . h...     5.0
# 1     Ambience is too good for a pleasant evening. S...     5.0
# 2     A must try.. great food great ambience. Thnx f...     5.0
# 3     Soumen das and Arun was a great guy. Only beca...     5.0
# 4     Food is good.we ordered Kodi drumsticks and ba...     5.0
# ...                                                 ...     ...
# 9995  Madhumathi Mahajan Well to start with nice cou...     3.0
# 9996  This place has never disappointed us.. The foo...     4.5
# 9997  Bad rating is mainly because of "Chicken Bone ...     1.5
# 9998  I personally love and prefer Chinese Food. Had...     4.0
# 9999  Checked in here to try some delicious chinese ...     3.5
#
#                           Metadata             Time  Pictures    7514
# 0           1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1          3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2          2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3            1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4          3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...                            ...              ...       ...     ...
# 9995     53 Reviews , 54 Followers    6/5/2016 0:08         0     NaN
# 9996      2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
# 9997    65 Reviews , 423 Followers   6/3/2016 10:37         3     NaN
# 9998    13 Reviews , 144 Followers  5/31/2016 17:22         0     NaN
# 9999  472 Reviews , 1302 Followers  5/31/2016 16:41         6     NaN
#
# [9964 rows x 8 columns]

# %%
#                 groupby - Grouping data: (Any 5) 
# 1. Group the dataset by Restaurant and find the average Rating for each city. 
df.groupby("Restaurant")["Rating"].mean()
# Out:
# Restaurant
# 10 Downing Street                        3.80
# 13 Dhaba                                 3.48
# 3B's - Buddies, Bar & Barbecue           4.76
# AB's - Absolute Barbecues                4.88
# Absolute Sizzlers                        3.62
#                                          ...
# Urban Asia - Kitchen & Bar               3.65
# Yum Yum Tree - The Arabian Food Court    3.56
# Zega - Sheraton Hyderabad Hotel          4.45
# Zing's Northeast Kitchen                 3.65
# eat.fit                                  3.20
# Name: Rating, Length: 100, dtype: float64

# %%
# 2. Group by Rating and get the count of each group in the Restaurant column. 
df.groupby("Rating")["Restaurant"].count()
# Out:
# Rating
# 1.0    1735
# 1.5       9
# 2.0     684
# 2.5      19
# 3.0    1193
# 3.5      47
# 4.0    2373
# 4.5      69
# 5.0    3832
# Name: Restaurant, dtype: int64

# %%
# 3. Group the data by Restaurant and calculate the total Pictures for each Restaurant category. 
df.groupby("Restaurant")["Pictures"].sum()
# Out:
# Restaurant
# 10 Downing Street                        105
# 13 Dhaba                                  41
# 3B's - Buddies, Bar & Barbecue            13
# AB's - Absolute Barbecues                 24
# Absolute Sizzlers                         45
#                                         ...
# Urban Asia - Kitchen & Bar               178
# Yum Yum Tree - The Arabian Food Court    129
# Zega - Sheraton Hyderabad Hotel           83
# Zing's Northeast Kitchen                 121
# eat.fit                                   58
# Name: Pictures, Length: 100, dtype: int64

# %%
# 4. Group by Restaurant and display the sum of Rating for each Restaurant group. 
df.groupby("Restaurant")["Rating"].sum()
# Out:
# Restaurant
# 10 Downing Street                        380.0
# 13 Dhaba                                 348.0
# 3B's - Buddies, Bar & Barbecue           476.0
# AB's - Absolute Barbecues                488.0
# Absolute Sizzlers                        362.0
#                                          ...
# Urban Asia - Kitchen & Bar               365.0
# Yum Yum Tree - The Arabian Food Court    356.0
# Zega - Sheraton Hyderabad Hotel          445.0
# Zing's Northeast Kitchen                 365.0
# eat.fit                                  320.0
# Name: Rating, Length: 100, dtype: float64

# %%
# 5. Group by Restaurant and find the number of unique entries in the Reviewer column. 
df.groupby("Restaurant")["Reviewer"].nunique()
# Out:
# Restaurant
# 10 Downing Street                        100
# 13 Dhaba                                  98
# 3B's - Buddies, Bar & Barbecue           100
# AB's - Absolute Barbecues                100
# Absolute Sizzlers                        100
#                                         ...
# Urban Asia - Kitchen & Bar               100
# Yum Yum Tree - The Arabian Food Court     98
# Zega - Sheraton Hyderabad Hotel          100
# Zing's Northeast Kitchen                 100
# eat.fit                                   95
# Name: Reviewer, Length: 100, dtype: int64

# %%
# 6. Group the dataset by Restaurant and find the maximum value of Pictures for each group.
df.groupby("Restaurant")["Pictures"].max()
# Out:
# Restaurant
# 10 Downing Street                        11
# 13 Dhaba                                  6
# 3B's - Buddies, Bar & Barbecue            3
# AB's - Absolute Barbecues                10
# Absolute Sizzlers                        22
#                                          ..
# Urban Asia - Kitchen & Bar               24
# Yum Yum Tree - The Arabian Food Court    14
# Zega - Sheraton Hyderabad Hotel          10
# Zing's Northeast Kitchen                  9
# eat.fit                                   8
# Name: Pictures, Length: 100, dtype: int64

# %%
#                 aggregation - Performing multiple aggregations: (Any 5) 
# 1. Group by Restaurant and calculate both the mean and median of the Rating column. 
df.groupby("Restaurant")["Rating"].mean()
# Out:
# Restaurant
# 10 Downing Street                        3.80
# 13 Dhaba                                 3.48
# 3B's - Buddies, Bar & Barbecue           4.76
# AB's - Absolute Barbecues                4.88
# Absolute Sizzlers                        3.62
#                                          ...
# Urban Asia - Kitchen & Bar               3.65
# Yum Yum Tree - The Arabian Food Court    3.56
# Zega - Sheraton Hyderabad Hotel          4.45
# Zing's Northeast Kitchen                 3.65
# eat.fit                                  3.20
# Name: Rating, Length: 100, dtype: float64

# %%
df.groupby("Restaurant")["Rating"].median()
# Out:
# Restaurant
# 10 Downing Street                        4.0
# 13 Dhaba                                 4.0
# 3B's - Buddies, Bar & Barbecue           5.0
# AB's - Absolute Barbecues                5.0
# Absolute Sizzlers                        4.0
#                                         ...
# Urban Asia - Kitchen & Bar               4.0
# Yum Yum Tree - The Arabian Food Court    4.0
# Zega - Sheraton Hyderabad Hotel          5.0
# Zing's Northeast Kitchen                 4.0
# eat.fit                                  4.0
# Name: Rating, Length: 100, dtype: float64

# %%
# 2. Perform multiple aggregations: find the sum, mean, and count of the Pictures column, 
# grouped by Restaurant. 
df.groupby("Restaurant")["Pictures"].agg(["sum","mean","count"]).reset_index()
# Out:
#                                Restaurant  sum  mean  count
# 0                       10 Downing Street  105  1.05    100
# 1                                13 Dhaba   41  0.41    100
# 2          3B's - Buddies, Bar & Barbecue   13  0.13    100
# 3               AB's - Absolute Barbecues   24  0.24    100
# 4                       Absolute Sizzlers   45  0.45    100
# ..                                    ...  ...   ...    ...
# 95             Urban Asia - Kitchen & Bar  178  1.78    100
# 96  Yum Yum Tree - The Arabian Food Court  129  1.29    100
# 97        Zega - Sheraton Hyderabad Hotel   83  0.83    100
# 98               Zing's Northeast Kitchen  121  1.21    100
# 99                                eat.fit   58  0.58    100
#
# [100 rows x 4 columns]

# %%
# 3. Group by Restaurant and apply min() and max() functions to the Pictures column. 
df.groupby("Restaurant").agg({
    "Pictures":["min","max"]
}).reset_index()
# Out:
#                                Restaurant Pictures
#                                                min max
# 0                       10 Downing Street        0  11
# 1                                13 Dhaba        0   6
# 2          3B's - Buddies, Bar & Barbecue        0   3
# 3               AB's - Absolute Barbecues        0  10
# 4                       Absolute Sizzlers        0  22
# ..                                    ...      ...  ..
# 95             Urban Asia - Kitchen & Bar        0  24
# 96  Yum Yum Tree - The Arabian Food Court        0  14
# 97        Zega - Sheraton Hyderabad Hotel        0  10
# 98               Zing's Northeast Kitchen        0   9
# 99                                eat.fit        0   8
#
# [100 rows x 3 columns]

# %%
# 4. Group by Restaurant and apply a custom aggregation function (e.g., find the range of Rating 
# within each city). 
df.groupby("Restaurant")["Rating"].agg(lambda x: x.max()-x.min())
# Out:
# Restaurant
# 10 Downing Street                        4.0
# 13 Dhaba                                 4.0
# 3B's - Buddies, Bar & Barbecue           4.0
# AB's - Absolute Barbecues                3.0
# Absolute Sizzlers                        4.0
#                                         ...
# Urban Asia - Kitchen & Bar               4.0
# Yum Yum Tree - The Arabian Food Court    4.0
# Zega - Sheraton Hyderabad Hotel          4.0
# Zing's Northeast Kitchen                 4.0
# eat.fit                                  4.0
# Name: Rating, Length: 100, dtype: float64

# %%
# 5. Group by Restaurant and calculate the average Rating, along with the total Pictures for each 
# group. 
df.groupby("Restaurant").agg({
    "Rating":"mean",
    "Pictures":"sum"
}).reset_index()
# Out:
#                                Restaurant  Rating  Pictures
# 0                       10 Downing Street    3.80       105
# 1                                13 Dhaba    3.48        41
# 2          3B's - Buddies, Bar & Barbecue    4.76        13
# 3               AB's - Absolute Barbecues    4.88        24
# 4                       Absolute Sizzlers    3.62        45
# ..                                    ...     ...       ...
# 95             Urban Asia - Kitchen & Bar    3.65       178
# 96  Yum Yum Tree - The Arabian Food Court    3.56       129
# 97        Zega - Sheraton Hyderabad Hotel    4.45        83
# 98               Zing's Northeast Kitchen    3.65       121
# 99                                eat.fit    3.20        58
#
# [100 rows x 3 columns]

# %%
# 6. Group the data by Restaurant and find both the standard deviation and the variance of the 
# Pictures.  
df.groupby("Restaurant")["Pictures"].agg(["std","var"]).reset_index()
# Out:
#                                Restaurant       std        var
# 0                       10 Downing Street  2.341436   5.482323
# 1                                13 Dhaba  1.083345   1.173636
# 2          3B's - Buddies, Bar & Barbecue  0.505625   0.255657
# 3               AB's - Absolute Barbecues  1.215390   1.477172
# 4                       Absolute Sizzlers  2.332792   5.441919
# ..                                    ...       ...        ...
# 95             Urban Asia - Kitchen & Bar  3.697064  13.668283
# 96  Yum Yum Tree - The Arabian Food Court  2.742464   7.521111
# 97        Zega - Sheraton Hyderabad Hotel  2.000278   4.001111
# 98               Zing's Northeast Kitchen  2.109598   4.450404
# 99                                eat.fit  1.304073   1.700606
#
# [100 rows x 3 columns]

# %%
#                 faker - Generating Fake Data for Testing: (All) 
# 1. Generate a fake dataset with 100 rows of random names, addresses, and dates using the 
# Faker library. 
import faker
fake= faker.Faker('en_IN')
data=[]
for _ in range(100):
    record={
        "Name": fake.name(),
        "Address": fake.address(),
        "Date": fake.date()
    }
    data.append(record)
fds= pd.DataFrame(data)
fds
# Out:
#                 Name                                   Address        Date
# 0     Frederick Vora            737, Ghose Marg, Nagpur 420552  2006-11-15
# 1        Teerth Bhat       71/518\nBumb Nagar, Jamalpur-232328  1974-12-12
# 2        Rishi Kunda      H.No. 30\nSaran Ganj\nGurgaon 906464  2000-01-11
# 3        Urvi Pillay        18/53\nPandya Ganj, Sonipat-897236  2009-08-03
# 4   Frederick Taneja     82/346\nIyengar Circle, Ujjain 285320  2008-06-19
# ..               ...                                       ...         ...
# 95   Chanakya Doctor   H.No. 068, Memon Circle\nKatihar-272928  2006-01-24
# 96     Nachiket Wali      02/30\nSetty Nagar, Nagercoil 300343  1992-03-13
# 97    Inaya Aggarwal        33, Agrawal Circle, Kolkata 124317  1992-09-07
# 98     Saanvi Sehgal             90, Sheth Path\nPurnia-103306  2016-08-10
# 99        Ekapad Lal  H.No. 53\nWarrior Marg, Panchkula 464998  2011-11-13
#
# [100 rows x 3 columns]

# %%
# 2. Create a list of 20 fake names and store them in a Name column. 
list= {'Name': [fake.name() for _ in range(20)]}
nameds= pd.DataFrame(list)
nameds
# Out:
#                   Name
# 0      Maanas Sundaram
# 1         Kalpit Lanka
# 2           Ekani Vasa
# 3            Nakul Rau
# 4            Simon Deo
# 5          Ekapad Iyer
# 6        Tripti Parmer
# 7       Harita Jhaveri
# 8       Triveni Sahota
# 9          Jasmit Kant
# 10        Anthony Nagy
# 11         Yatin Batra
# 12   Qadim Ranganathan
# 13       Caleb Narayan
# 14     Falguni Narayan
# 15          Rachit Som
# 16     Aashi Chaudhary
# 17      Ekiya Sengupta
# 18        Anita Mander
# 19  Brijesh Narasimhan

# %%
# 3. Generate fake email addresses and store them in a column called Email. 
list= {'Name': [fake.address() for _ in range(20)]}
addressds= pd.DataFrame(list)
addressds
# Out:
#                                                 Name
# 0           H.No. 63, Acharya Marg, Ghaziabad 046021
# 1                   39/21, Sani Path, Udaipur-667877
# 2                  49\nIssac Path, Saharanpur-564138
# 3         38/038, Tak Street\nTiruchirappalli-418481
# 4                      17\nGolla Path, Rohtak 357848
# 5      H.No. 81\nMahajan Street\nNorth Dumdum-941306
# 6            20/38, Narayanan Ganj, Dibrugarh 940865
# 7                       25, Garde Road, Siwan 756023
# 8               H.No. 371\nSawhney Zila\nGaya 664549
# 9                75/972\nSarna Marg\nAmravati 764226
# 10                656\nNori Path, Bhubaneswar-198002
# 11                  95, Sankaran Road, Munger-519800
# 12                   45/247, Sodhi Marg, Rewa 984842
# 13           77/276, Nagarajan Circle, Bhilai-224376
# 14         267, Balasubramanian Marg, Asansol-148692
# 15            H.No. 71\nMander Path, Bareilly 602826
# 16                  259\nButala Zila\nVellore-433613
# 17             H.No. 831, Char Chowk, Raiganj-133531
# 18        H.No. 91\nDhillon Marg\nMiryalaguda 060010
# 19  17/18\nMukhopadhyay Circle, Hubli–Dharwad 075444

# %%
# 4. Generate fake dates of birth and convert them into an Age column using Faker. 
from datetime import datetime
dob_list = [fake.date_of_birth(minimum_age=18, maximum_age=80) for _ in range(20)]
age_data = {'Date_of_Birth': dob_list, 'Age': [(datetime.today().year - dob.year) for dob in dob_list]}
dobds = pd.DataFrame(age_data)
dobds
# Out:
#    Date_of_Birth  Age
# 0     1990-01-06   35
# 1     1988-01-22   37
# 2     2004-03-29   21
# 3     1969-03-27   56
# 4     1967-05-08   58
# 5     1966-09-10   59
# 6     1977-12-10   48
# 7     1970-10-15   55
# 8     1979-06-05   46
# 9     1944-03-25   81
# 10    1971-08-05   54
# 11    1996-02-22   29
# 12    1992-12-18   33
# 13    1971-04-14   54
# 14    1946-02-25   79
# 15    1999-05-30   26
# 16    1970-07-13   55
# 17    1947-10-08   78
# 18    2001-05-28   24
# 19    1968-04-09   57

# %%
# 5. Generate fake product names, and then create a DataFrame with columns for 
# Product_Name and Price. 
import random
product_data = {
    'Product_Name': [fake.word().capitalize() for _ in range(20)],
    'Price': [round(random.uniform(10, 500), 2) for _ in range(20)]
}
prodds = pd.DataFrame(product_data)
prodds
# Out:
#    Product_Name   Price
# 0            Ea  347.62
# 1            Ab  143.94
# 2        Libero  119.57
# 3      Eligendi  157.15
# 4             A  455.01
# 5          Odit   87.16
# 6   Repudiandae  388.65
# 7         Vitae  449.03
# 8         Dolor  292.93
# 9         Neque  136.05
# 10       Maxime   42.56
# 11        Totam  278.16
# 12      Officia  296.87
# 13        Ipsum  194.72
# 14        Ullam  388.02
# 15          Sit  451.38
# 16  Perferendis  474.64
# 17     Repellat  317.68
# 18   Temporibus  194.44
# 19         Illo  400.35

# %%
# 6. Use the Faker library to create a DataFrame with fake user information, including Name, 
# City, and Phone Number. 
user_data = {
    'Name': [fake.name() for _ in range(20)],
    'City': [fake.city() for _ in range(20)],
    'Phone_Number': [fake.phone_number() for _ in range(20)]
}
userds = pd.DataFrame(user_data)
userds
# Out:
#                    Name                  City   Phone_Number
# 0          Noah Sachdev                 Arrah  +917390392348
# 1          Advika Setty                Karnal     2333275984
# 2           Vivaan Vala             Baranagar  +912167924345
# 3   Bhanumati Chaudhuri              Bathinda    03384601852
# 4           Gautam Lala           Pondicherry     9895939060
# 5           Mohini Shan  Kirari Suleman Nagar     3719537451
# 6        Geetika Saxena           Mahbubnagar  +911451010864
# 7           Ishani Dara              Vadodara     1328200056
# 8             Ati Dixit             Sambalpur     3130977720
# 9    Abhimanyu Sachdeva                  Agra     7971417836
# 10        Nathan Shenoy               Katihar    08184324071
# 11          Hiral Kalla              Durgapur  +911023826779
# 12           Wyatt Kaur                 Kochi     6082954388
# 13         Raagini Sood                Phusro  +911121246833
# 14           Oeshi Ravi                Ranchi    08753161172
# 15           Logan Dave  Bhalswa Jahangir Pur  +912731681198
# 16           Oviya Bava            Bhimavaram  +913318866267
# 17           Aashi Vyas                Etawah    03337873419
# 18         Vincent Kata                Kadapa  +917332917143
# 19        Chameli Handa                Nagaon    08406288573

# %%
#                 merge - Merging DataFrames: (All) 
# 1. Merge two DataFrames on a common column Product_ID. 
df1 = pd.DataFrame({
    'Product_ID': [101, 102, 103, 104],
    'Product_Name': ['Laptop', 'Phone', 'Tablet', 'Monitor'],
    'Price': [1000, 500, 300, 200]
})

df2 = pd.DataFrame({
    'Product_ID': [102, 103, 104, 105],
    'Category': ['Electronics', 'Electronics', 'Accessories', 'Gaming'],
    'Stock': [50, 30, 20, 10]
})

pd.merge(df1, df2, on='Product_ID')
# Out:
#    Product_ID Product_Name  Price     Category  Stock
# 0         102        Phone    500  Electronics     50
# 1         103       Tablet    300  Electronics     30
# 2         104      Monitor    200  Accessories     20

# %%
# 2. Perform a left join between two DataFrames based on Employee_ID. 
df_emp1 = pd.DataFrame({
    'Employee_ID': [1, 2, 3, 4],
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Department': ['HR', 'IT', 'Finance', 'Marketing']
})

df_emp2 = pd.DataFrame({
    'Employee_ID': [2, 3, 5, 6],
    'Salary': [60000, 70000, 80000, 90000]
})

pd.merge(df_emp1, df_emp2, on='Employee_ID', how='left')
# Out:
#    Employee_ID     Name Department   Salary
# 0            1    Alice         HR      NaN
# 1            2      Bob         IT  60000.0
# 2            3  Charlie    Finance  70000.0
# 3            4    David  Marketing      NaN

# %%
# 3. Merge two DataFrames, keeping all rows from the left DataFrame and matching rows 
# from the right. 
pd.merge(df1, df2, on='Product_ID', how='left')
# Out:
#    Product_ID Product_Name  Price     Category  Stock
# 0         101       Laptop   1000          NaN    NaN
# 1         102        Phone    500  Electronics   50.0
# 2         103       Tablet    300  Electronics   30.0
# 3         104      Monitor    200  Accessories   20.0

# %%
# 4. Merge two DataFrames on multiple columns (e.g., City and Age). 
df_city1 = pd.DataFrame({
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston'],
    'Age': [25, 30, 35, 40],
    'Population': [8000000, 4000000, 2700000, 2300000]
})

df_city2 = pd.DataFrame({
    'City': ['New York', 'Los Angeles', 'Chicago', 'San Francisco'],
    'Age': [25, 30, 35, 45],
    'Income': [50000, 60000, 55000, 70000]
})

pd.merge(df_city1, df_city2, on=['City', 'Age'])
# Out:
#           City  Age  Population  Income
# 0     New York   25     8000000   50000
# 1  Los Angeles   30     4000000   60000
# 2      Chicago   35     2700000   55000

# %%
# 5. Perform an inner join on two DataFrames with a common column Country. 
df_country1 = pd.DataFrame({
    'Country': ['USA', 'Canada', 'Germany', 'France'],
    'Capital': ['Washington', 'Ottawa', 'Berlin', 'Paris']
})

df_country2 = pd.DataFrame({
    'Country': ['USA', 'Canada', 'UK', 'Australia'],
    'Currency': ['USD', 'CAD', 'GBP', 'AUD']
})

pd.merge(df_country1, df_country2, on='Country', how='inner')
# Out:
#   Country     Capital Currency
# 0     USA  Washington      USD
# 1  Canada      Ottawa      CAD

# %%
# 6. Merge two DataFrames and keep all rows, even if there’s no match in the second 
# DataFrame. 
pd.merge(df1, df2, on='Product_ID', how='outer')
# Out:
#    Product_ID Product_Name   Price     Category  Stock
# 0         101       Laptop  1000.0          NaN    NaN
# 1         102        Phone   500.0  Electronics   50.0
# 2         103       Tablet   300.0  Electronics   30.0
# 3         104      Monitor   200.0  Accessories   20.0
# 4         105          NaN     NaN       Gaming   10.0

# %%
#                 Saving and Exporting Data: (All) 
# 1. Save the DataFrame to a new CSV file. 
userds.to_csv("userData.csv", index=False)

# %%
# 2. Export the DataFrame to an Excel file. 
userds.to_excel("userData.xlsx", index=False)

# %%
df
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review  Rating  \
# 0     The ambience was good, food was quite good . h...     5.0
# 1     Ambience is too good for a pleasant evening. S...     5.0
# 2     A must try.. great food great ambience. Thnx f...     5.0
# 3     Soumen das and Arun was a great guy. Only beca...     5.0
# 4     Food is good.we ordered Kodi drumsticks and ba...     5.0
# ...                                                 ...     ...
# 9995  Madhumathi Mahajan Well to start with nice cou...     3.0
# 9996  This place has never disappointed us.. The foo...     4.5
# 9997  Bad rating is mainly because of "Chicken Bone ...     1.5
# 9998  I personally love and prefer Chinese Food. Had...     4.0
# 9999  Checked in here to try some delicious chinese ...     3.5
#
#                           Metadata             Time  Pictures    7514
# 0           1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1          3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2          2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3            1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4          3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...                            ...              ...       ...     ...
# 9995     53 Reviews , 54 Followers    6/5/2016 0:08         0     NaN
# 9996      2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
# 9997    65 Reviews , 423 Followers   6/3/2016 10:37         3     NaN
# 9998    13 Reviews , 144 Followers  5/31/2016 17:22         0     NaN
# 9999  472 Reviews , 1302 Followers  5/31/2016 16:41         6     NaN
#
# [9964 rows x 8 columns]

# %%
#                     COMPULSORY QUESTION: 
# 1. Complex Filtering and Aggregation: 
# ● Filter the dataset for all rows where the Rating is between 0 and 4 and the Pictures is less than 10 
# ● Then, group the filtered data by Restaurant and calculate both the mean and median of the Rating column. 
# ● After that, sort the result in descending order by the Rating column. 

dataset= df[((df["Rating"]>0)&(df["Rating"]<4))& (df["Pictures"]<10)]
dsGroup= dataset.groupby("Restaurant")["Rating"].agg(["mean","median"]).reset_index()
dsGroup.sort_values(by="mean", ascending=False)
# Out:
#                                  Restaurant      mean  median
# 97          Zega - Sheraton Hyderabad Hotel  2.636364     3.0
# 19  Cascade - Radisson Hyderabad Hitec City  2.636364     3.0
# 87                           The Indi Grill  2.625000     3.0
# 48                                KS Bakers  2.500000     3.0
# 20                         Chinese Pavilion  2.469697     3.0
# ..                                      ...       ...     ...
# 67                                 Paradise  1.500000     1.0
# 72                   Royal Spicy Restaurant  1.484848     1.0
# 59                      Mohammedia Shawarma  1.472727     1.0
# 41                         Hotel Zara Hi-Fi  1.328571     1.0
# 29                           Domino's Pizza  1.320000     1.0
#
# [100 rows x 3 columns]

# %%
# 2. Advanced String Manipulation and Grouping: 
# ● Create a new column Reviewer by concatenating the First and Last columns with a space in between. 
# ● Then, split the Reviewer column into two separate columns: First and Last. 
# ● Finally, group the dataset by Restaurant and calculate the count of unique Reviewer entries for each Restaurant. 
dfcopy[["First","Last"]]=dfcopy["Reviewer"].str.split(" ",n=1,expand=True)
dfcopy
dfcopy.drop(columns="Reviewer")
# Out:
#             Restaurant                                             Review  \
# 0      Beyond Flavours  The ambience was good, food was quite good . h...
# 1      Beyond Flavours  Ambience is too good for a pleasant evening. S...
# 2      Beyond Flavours  A must try.. great food great ambience. Thnx f...
# 3      Beyond Flavours  Soumen das and Arun was a great guy. Only beca...
# 4      Beyond Flavours  Food is good.we ordered Kodi drumsticks and ba...
# ...                ...                                                ...
# 9995  Chinese Pavilion  Madhumathi Mahajan Well to start with nice cou...
# 9996  Chinese Pavilion  This place has never disappointed us.. The foo...
# 9997  Chinese Pavilion  Bad rating is mainly because of "Chicken Bone ...
# 9998  Chinese Pavilion  I personally love and prefer Chinese Food. Had...
# 9999  Chinese Pavilion  Checked in here to try some delicious chinese ...
#
#       Rating                      Metadata             Time  Pictures    7514  \
# 0        5.0        1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1        5.0       3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2        5.0       2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3        5.0         1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4        5.0       3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...      ...                           ...              ...       ...     ...
# 9995     3.0     53 Reviews , 54 Followers    6/5/2016 0:08         0     NaN
# 9996     4.5      2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
# 9997     1.5    65 Reviews , 423 Followers   6/3/2016 10:37         3     NaN
# 9998     4.0    13 Reviews , 144 Followers  5/31/2016 17:22         0     NaN
# 9999     3.5  472 Reviews , 1302 Followers  5/31/2016 16:41         6     NaN
#
#           First           Last
# 0         Rusha    Chakraborty
# 1        Anusha  Tirumalaneedi
# 2         Ashok      Shekhawat
# 3       Swapnil         Sarkar
# 4        Dileep
# ...         ...            ...
# 9995   Abhishek        Mahajan
# 9996     Sharad        Agrawal
# 9997  Ramandeep
# 9998     Nayana       Shanbhag
# 9999   Bhargava        Krishna
#
# [9964 rows x 9 columns]

# %%
dfcopy["Reviewer"]= dfcopy["First"]+" "+dfcopy["Last"]
dfcopy
# Out:
#             Restaurant                                             Review  \
# 0      Beyond Flavours  The ambience was good, food was quite good . h...
# 1      Beyond Flavours  Ambience is too good for a pleasant evening. S...
# 2      Beyond Flavours  A must try.. great food great ambience. Thnx f...
# 3      Beyond Flavours  Soumen das and Arun was a great guy. Only beca...
# 4      Beyond Flavours  Food is good.we ordered Kodi drumsticks and ba...
# ...                ...                                                ...
# 9995  Chinese Pavilion  Madhumathi Mahajan Well to start with nice cou...
# 9996  Chinese Pavilion  This place has never disappointed us.. The foo...
# 9997  Chinese Pavilion  Bad rating is mainly because of "Chicken Bone ...
# 9998  Chinese Pavilion  I personally love and prefer Chinese Food. Had...
# 9999  Chinese Pavilion  Checked in here to try some delicious chinese ...
#
#       Rating                      Metadata             Time  Pictures    7514  \
# 0        5.0        1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1        5.0       3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2        5.0       2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3        5.0         1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4        5.0       3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
# ...      ...                           ...              ...       ...     ...
# 9995     3.0     53 Reviews , 54 Followers    6/5/2016 0:08         0     NaN
# 9996     4.5      2 Reviews , 53 Followers   6/4/2016 22:01         0     NaN
# 9997     1.5    65 Reviews , 423 Followers   6/3/2016 10:37         3     NaN
# 9998     4.0    13 Reviews , 144 Followers  5/31/2016 17:22         0     NaN
# 9999     3.5  472 Reviews , 1302 Followers  5/31/2016 16:41         6     NaN
#
#                   Reviewer      First           Last
# 0        Rusha Chakraborty      Rusha    Chakraborty
# 1     Anusha Tirumalaneedi     Anusha  Tirumalaneedi
# 2          Ashok Shekhawat      Ashok      Shekhawat
# 3           Swapnil Sarkar    Swapnil         Sarkar
# 4                  Dileep      Dileep
# ...                    ...        ...            ...
# 9995      Abhishek Mahajan   Abhishek        Mahajan
# 9996        Sharad Agrawal     Sharad        Agrawal
# 9997            Ramandeep   Ramandeep
# 9998       Nayana Shanbhag     Nayana       Shanbhag
# 9999      Bhargava Krishna   Bhargava        Krishna
#
# [9964 rows x 10 columns]

# %%
dfcopy.groupby(by="Restaurant")["Reviewer"].nunique()
# Out:
# Restaurant
# 10 Downing Street                        100
# 13 Dhaba                                  98
# 3B's - Buddies, Bar & Barbecue           100
# AB's - Absolute Barbecues                100
# Absolute Sizzlers                        100
#                                         ...
# Urban Asia - Kitchen & Bar               100
# Yum Yum Tree - The Arabian Food Court     98
# Zega - Sheraton Hyderabad Hotel          100
# Zing's Northeast Kitchen                 100
# eat.fit                                   95
# Name: Reviewer, Length: 100, dtype: int64

# %%
# 3. Multiple Data Transformations and Merging: 
# ● Normalize the Rating column to scale the values between 0 and 1. 
# ● Replace any negative values in the Pictures column with the median of the column. 
# ● Merge the cleaned dataset with another DataFrame (say, product_data) based on the 
# Reviewer column and display the first 5 rows of the merged dataset.

data={
    "Reviewer":["Rusha Chakraborty","Anusha Tirumalaneedi","Ashok Shekhawat","Swapnil Sarkar","Dileep","Ramandeep","Nayana Shanbhag","Bhargava Krishna"],
    "Age":[34,32,32,31,28,26,29,22]
}
ageds= pd.DataFrame(data)

copydf= df.copy()
copydf["Normalized Rating"]= (copydf["Rating"] - copydf["Rating"].min()) / (copydf["Rating"].max() - copydf["Rating"].min())
median_age = copydf[copydf['Pictures'] >= 0]['Pictures'].median()
copydf['Pictures'] = copydf['Pictures'].apply(lambda x: median_age if x < 0 else x)
mergedds= pd.merge(copydf,ageds, on= "Reviewer")
mergedds.head()
# Out:
#         Restaurant              Reviewer  \
# 0  Beyond Flavours     Rusha Chakraborty
# 1  Beyond Flavours  Anusha Tirumalaneedi
# 2  Beyond Flavours       Ashok Shekhawat
# 3  Beyond Flavours        Swapnil Sarkar
# 4  Beyond Flavours                Dileep
#
#                                               Review  Rating  \
# 0  The ambience was good, food was quite good . h...     5.0
# 1  Ambience is too good for a pleasant evening. S...     5.0
# 2  A must try.. great food great ambience. Thnx f...     5.0
# 3  Soumen das and Arun was a great guy. Only beca...     5.0
# 4  Food is good.we ordered Kodi drumsticks and ba...     5.0
#
#                   Metadata             Time  Pictures    7514  \
# 0   1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1  3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2  2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3    1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4  3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN
#
#    Normalized Rating  Age
# 0                1.0   34
# 1                1.0   32
# 2                1.0   32
# 3                1.0   31
# 4                1.0   28

# %%
# 1. Create a DataFrame with 'Product ID', 'Product Name', 'Quantity', and 'Price'. Add 10 
# rows of data for different products. Perform an operation to calculate the 'Total Value' 
# (Quantity * Price) and add it as a new column. Export the modified DataFrame to an 
# Excel file and compare the original and modified versions. What changes can you 
# observe in the data? 
product_data = {
    "Product ID": [fake.unique.random_int(min=1000, max=9999) for _ in range(10)],
    "Product Name": [fake.word().capitalize() for _ in range(10)],
    "Quantity": [random.randint(1, 50) for _ in range(10)],
    "Price": [round(random.uniform(10, 1000), 2) for _ in range(10)]
}

Oproddf = pd.DataFrame(product_data)
Mproddf = Oproddf.copy()
Mproddf["Total Value"] = Mproddf["Quantity"] * Mproddf["Price"]

with pd.ExcelWriter("product.xlsx") as writer:
    Oproddf.to_excel(writer, sheet_name="Original Data", index=False)
    Mproddf.to_excel(writer, sheet_name="Modified Data", index=False)

print("Original DataFrame:\n", Oproddf)
print("\nModified DataFrame with 'Total Value':\n", Mproddf)
# Out:
# Original DataFrame:
#     Product ID Product Name  Quantity   Price
# 0        3855        Ullam        17  913.39
# 1        2142      Dolorum        16  538.25
# 2        2408     Incidunt        30   14.71
# 3        7015            A        13  891.03
# 4        9803    Accusamus         5  555.36
# 5        8023  Repudiandae         5  108.21
# 6        9536      Numquam        11  698.38
# 7        5125        Alias         5  318.61
# 8        2004         Ipsa        33  673.01
# 9        2456         Nisi        12  618.99
#
# Modified DataFrame with 'Total Value':
#     Product ID Product Name  Quantity   Price  Total Value
# 0        3855        Ullam        17  913.39     15527.63
# 1        2142      Dolorum        16  538.25      8612.00
# 2        2408     Incidunt        30   14.71       441.30
# 3        7015            A        13  891.03     11583.39
# 4        9803    Accusamus         5  555.36      2776.80
# 5        8023  Repudiandae         5  108.21       541.05
# 6        9536      Numquam        11  698.38      7682.18
# 7        5125        Alias         5  318.61      1593.05
# 8        2004         Ipsa        33  673.01     22209.33
# 9        2456         Nisi        12  618.99      7427.88

# %%
# 2. Create a DataFrame with 'Student ID', 'Name', 'Grade', and 'Score'. Add 10 rows with 
# data. Perform an operation to assign a 'Pass/Fail' status based on whether the score is 
# above 50 (Pass) or below 50 (Fail). Export the modified DataFrame to an Excel file and 
# show the comparison between the initial file and the updated one. What new columns or 
# changes can you see?

student_data = {
    "Student ID": [fake.unique.random_int(min=1000, max=9999) for _ in range(10)],
    "Name": [fake.name() for _ in range(10)],
    "Grade": [random.choice(['A', 'B', 'C', 'D', 'E']) for _ in range(10)],
    "Score": [random.randint(30, 100) for _ in range(10)]  # Random scores between 30 and 100
}

original_df = pd.DataFrame(student_data)

modified_df = original_df.copy()
modified_df['Pass/Fail'] = modified_df['Score'].apply(lambda x: 'Pass' if x >= 50 else 'Fail')

with pd.ExcelWriter("students_comparison.xlsx") as writer:
    original_df.to_excel(writer, sheet_name="Original Data", index=False)
    modified_df.to_excel(writer, sheet_name="Modified Data", index=False)

print("Original DataFrame:\n", original_df)
print("\nModified DataFrame with 'Pass/Fail' Status:\n", modified_df)
# Out:
# Original DataFrame:
#     Student ID                Name Grade  Score
# 0        8121         Oliver Dash     C     47
# 1        6259     Yochana Solanki     A     80
# 2        5046       Shravya Amble     D     39
# 3        2055        Yutika Datta     C     75
# 4        5902       Jairaj Mander     A     47
# 5        3207        Daksha Raman     B     43
# 6        5052       Ekavir Thakur     E     42
# 7        5142          Anika Kata     A     79
# 8        3381         Bhavya Kota     E     37
# 9        7432  Ucchal Padmanabhan     C     93
#
# Modified DataFrame with 'Pass/Fail' Status:
#     Student ID                Name Grade  Score Pass/Fail
# 0        8121         Oliver Dash     C     47      Fail
# 1        6259     Yochana Solanki     A     80      Pass
# 2        5046       Shravya Amble     D     39      Fail
# 3        2055        Yutika Datta     C     75      Pass
# 4        5902       Jairaj Mander     A     47      Fail
# 5        3207        Daksha Raman     B     43      Fail
# 6        5052       Ekavir Thakur     E     42      Fail
# 7        5142          Anika Kata     A     79      Pass
# 8        3381         Bhavya Kota     E     37      Fail
# 9        7432  Ucchal Padmanabhan     C     93      Pass

# %%
# 1. Create a CSV file and an Excel file with columns 'Student ID', 'Name', 'Grade', and 
# 'Score'. Add 5 rows of student data to each file. Upload the files to Jupyter Notebook, 
# then perform an operation to assign a 'Pass/Fail' status based on whether the score is 
# above 50. Export the modified CSV and Excel files and compare them with the originals. 
# Explain the differences and the new columns added. 

student_data = {
    "Student ID": [fake.unique.random_int(min=1000, max=9999) for _ in range(5)],
    "Name": [fake.name() for _ in range(5)],
    "Grade": [random.choice(['A', 'B', 'C', 'D', 'E']) for _ in range(5)],
    "Score": [random.randint(30, 100) for _ in range(5)]  # Random scores between 30-100
}

df = pd.DataFrame(student_data)

# Save as CSV and Excel
df.to_csv("students.csv", index=False)
df.to_excel("students.xlsx", sheet_name="Original Data", index=False)

print("Original CSV and Excel files created successfully!")
# Out:
# Original CSV and Excel files created successfully!

# %%
df_csv = pd.read_csv("students.csv")

df_excel = pd.read_excel("students.xlsx", sheet_name="Original Data")

print("Files successfully loaded into DataFrames!")
# Out:
# Files successfully loaded into DataFrames!

# %%
df_csv["Pass/Fail"] = df_csv["Score"].apply(lambda x: "Pass" if x >= 50 else "Fail")
df_excel["Pass/Fail"] = df_excel["Score"].apply(lambda x: "Pass" if x >= 50 else "Fail")

print("Pass/Fail column added successfully!")
# Out:
# Pass/Fail column added successfully!

# %%
df_csv.to_csv("students_modified.csv", index=False)
df_excel.to_excel("students_modified.xlsx", sheet_name="Modified Data", index=False)

print("Modified CSV and Excel files exported successfully!")
# Out:
# Modified CSV and Excel files exported successfully!

# %%
# 2. Create a CSV file and an Excel file with 'City', 'Country', 'Population', and 'Area'. Add 5 
# rows of city data to both files. Upload the files to Jupyter Notebook, then perform an 
# operation to calculate the 'Population Density' (Population / Area) and add it as a new 
# column. Export both files after modification and compare the original and updated files. 
# What new information can you observe in the 'Population Density' column? 

city_data = {
    "City": ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix"],
    "Country": ["USA", "USA", "USA", "USA", "USA"],
    "Population": [8419600, 3980400, 2716000, 2328000, 1690000],  # Sample population data
    "Area": [783.8, 1302, 589, 1625, 1340]  # Sample area in square km
}

df = pd.DataFrame(city_data)

df.to_csv("cities.csv", index=False)
df.to_excel("cities.xlsx", sheet_name="Original Data", index=False)

print("Original CSV and Excel files created successfully!")
# Out:
# Original CSV and Excel files created successfully!

# %%
df_csv = pd.read_csv("cities.csv")

df_excel = pd.read_excel("cities.xlsx", sheet_name="Original Data")

print("Files successfully loaded into DataFrames!")
# Out:
# Files successfully loaded into DataFrames!

# %%
df_csv["Population Density"] = df_csv["Population"] / df_csv["Area"]
df_excel["Population Density"] = df_excel["Population"] / df_excel["Area"]

print("Population Density column added successfully!")
# Out:
# Population Density column added successfully!

# %%
df_csv.to_csv("cities_modified.csv", index=False)
df_excel.to_excel("cities_modified.xlsx", sheet_name="Modified Data", index=False)

print("Modified CSV and Excel files exported successfully!")
# Out:
# Modified CSV and Excel files exported successfully!
