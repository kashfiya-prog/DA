# %%
import pandas as pd

# %%
ds = pd.read_csv("StudentDepressionDataset.csv")

# %%
print(ds)
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
ds.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
#display first 5 rows of dataset
ds.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
#display last 5 rows of dataset
ds.tail()
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 27896  140685  Female  27.0      Surat    Student                5.0
# 27897  140686    Male  27.0   Ludhiana    Student                2.0
# 27898  140689    Male  31.0  Faridabad    Student                3.0
# 27899  140690  Female  18.0   Ludhiana    Student                5.0
# 27900  140699    Male  27.0      Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 27896            0.0  5.75                 5.0               0.0
# 27897            0.0  9.40                 3.0               0.0
# 27898            0.0  6.61                 4.0               0.0
# 27899            0.0  6.88                 2.0               0.0
# 27900            0.0  9.24                 1.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 27896          5-6 hours      Unhealthy  Class 12
# 27897  Less than 5 hours        Healthy       MSc
# ...

# %%
#display number of counts of rows and columns
ds.shape
# Out:
# (27901, 18)

# %%
#display summary or infomation about dataset including data types and not null counts
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
#get descriptive statistics for numerical column in database
ds.describe
# Out:
# <bound method NDFrame.describe of            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
# ...

# %%
ds.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %%
#select the age column from dataset
ds['Age']
# Out:
# 0        33.0
# 1        24.0
# 2        31.0
# 3        28.0
# 4        25.0
#          ...
# 27896    27.0
# 27897    27.0
# 27898    31.0
# 27899    18.0
# 27900    27.0
# Name: Age, Length: 27901, dtype: float64

# %%
ds[['CGPA','Age']]
# Out:
#        CGPA   Age
# 0      8.97  33.0
# 1      5.90  24.0
# 2      7.03  31.0
# 3      5.59  28.0
# 4      8.13  25.0
# ...     ...   ...
# 27896  5.75  27.0
# 27897  9.40  27.0
# 27898  6.61  31.0
# 27899  6.88  18.0
# 27900  9.24  27.0
#
# [27901 rows x 2 columns]

# %%
#select the first row from the dataset by index
ds.iloc[0]
# Out:
# id                                                   2
# Gender                                            Male
# Age                                               33.0
# City                                     Visakhapatnam
# Profession                                     Student
# Academic Pressure                                  5.0
# Work Pressure                                      0.0
# CGPA                                              8.97
# Study Satisfaction                                 2.0
# Job Satisfaction                                   0.0
# Sleep Duration                               5-6 hours
# Dietary Habits                                 Healthy
# Degree                                         B.Pharm
# Have you ever had suicidal thoughts ?              Yes
# Work/Study Hours                                   3.0
# Financial Stress                                   1.0
# Family History of Mental Illness                    No
# ...

# %%
#select the row with label index 0 from dataset
ds.loc[0]
# Out:
# id                                                   2
# Gender                                            Male
# Age                                               33.0
# City                                     Visakhapatnam
# Profession                                     Student
# Academic Pressure                                  5.0
# Work Pressure                                      0.0
# CGPA                                              8.97
# Study Satisfaction                                 2.0
# Job Satisfaction                                   0.0
# Sleep Duration                               5-6 hours
# Dietary Habits                                 Healthy
# Degree                                         B.Pharm
# Have you ever had suicidal thoughts ?              Yes
# Work/Study Hours                                   3.0
# Financial Stress                                   1.0
# Family History of Mental Illness                    No
# ...

# %%
#select rows from 1 to 5 and column from 2 to 5
ds.iloc[0:5,1:5]
# Out:
#    Gender   Age           City Profession
# 0    Male  33.0  Visakhapatnam    Student
# 1  Female  24.0      Bangalore    Student
# 2    Male  31.0       Srinagar    Student
# 3  Female  28.0       Varanasi    Student
# 4  Female  25.0         Jaipur    Student

# %%
ds.loc[1:5,2:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 ds.loc[1:5,2:5]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1020, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
# ...

# %%
#filter the dataset for rows where age is greater than 30
ds[ds['Age']>30.0]
# Out:
#            id Gender   Age           City Profession  Academic Pressure  \
# 0           2   Male  33.0  Visakhapatnam    Student                5.0
# 2          26   Male  31.0       Srinagar    Student                3.0
# 9          62   Male  31.0         Nashik    Student                2.0
# 11         91   Male  33.0       Vadodara    Student                3.0
# 26        186   Male  31.0      Ahmedabad    Student                2.0
# ...       ...    ...   ...            ...        ...                ...
# 27876  140536   Male  33.0         Nagpur    Student                1.0
# 27887  140624   Male  32.0         Rajkot    Student                4.0
# 27889  140631   Male  33.0      Ahmedabad    Student                1.0
# 27895  140684   Male  31.0        Lucknow    Student                2.0
# 27898  140689   Male  31.0      Faridabad    Student                3.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
#use the query method to filter rows where age is greater than 30
ds.query('Age>30.0')
# Out:
#            id Gender   Age           City Profession  Academic Pressure  \
# 0           2   Male  33.0  Visakhapatnam    Student                5.0
# 2          26   Male  31.0       Srinagar    Student                3.0
# 9          62   Male  31.0         Nashik    Student                2.0
# 11         91   Male  33.0       Vadodara    Student                3.0
# 26        186   Male  31.0      Ahmedabad    Student                2.0
# ...       ...    ...   ...            ...        ...                ...
# 27876  140536   Male  33.0         Nagpur    Student                1.0
# 27887  140624   Male  32.0         Rajkot    Student                4.0
# 27889  140631   Male  33.0      Ahmedabad    Student                1.0
# 27895  140684   Male  31.0        Lucknow    Student                2.0
# 27898  140689   Male  31.0      Faridabad    Student                3.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
#check if there are any missing values in dataframe
ds.isnull()
# Out:
#           id  Gender    Age   City  Profession  Academic Pressure  \
# 0      False   False  False  False       False              False
# 1      False   False  False  False       False              False
# 2      False   False  False  False       False              False
# 3      False   False  False  False       False              False
# 4      False   False  False  False       False              False
# ...      ...     ...    ...    ...         ...                ...
# 27896  False   False  False  False       False              False
# 27897  False   False  False  False       False              False
# 27898  False   False  False  False       False              False
# 27899  False   False  False  False       False              False
# 27900  False   False  False  False       False              False
#
#        Work Pressure   CGPA  Study Satisfaction  Job Satisfaction  \
# 0              False  False               False             False
# ...

# %%
#count the number of missing values in the dataset
ds.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
#fill missing values with 0
ds.fillna(0, inplace=True)

# %%
ds.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
#check the datatype of column
ds.dtypes
# Out:
# id                                         int64
# Gender                                    object
# Age                                      float64
# City                                      object
# Profession                                object
# Academic Pressure                        float64
# Work Pressure                            float64
# CGPA                                     float64
# Study Satisfaction                       float64
# Job Satisfaction                         float64
# Sleep Duration                            object
# Dietary Habits                            object
# Degree                                    object
# Have you ever had suicidal thoughts ?     object
# Work/Study Hours                         float64
# Financial Stress                         float64
# Family History of Mental Illness          object
# Depression                                 int64
# dtype: object

# %%
#sort the data set or dataframe based on specific column
ds.sort_values(by='Age',ascending=False)
# Out:
#            id  Gender   Age      City Profession  Academic Pressure  \
# 9238    46602    Male  59.0    Nashik    Student                1.0
# 2909    14768  Female  58.0   Chennai    Student                4.0
# 14819   74887  Female  56.0  Ludhiana    Student                3.0
# 13499   68441    Male  54.0      Agra    Student                5.0
# 4386    22004  Female  51.0    Bhopal    Student                2.0
# ...       ...     ...   ...       ...        ...                ...
# 15856   80171    Male  18.0    Jaipur    Student                1.0
# 15870   80239  Female  18.0   Lucknow    Student                3.0
# 15871   80246  Female  18.0    Indore    Student                5.0
# 15873   80270    Male  18.0    Rajkot    Student                4.0
# 22537  113642  Female  18.0  Ludhiana    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 9238             0.0  8.14                 1.0               0.0
# ...

# %%
ds.sort_values(by='Age').head()
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 9100    45903    Male  18.0       Agra    Student                3.0
# 9867    49784  Female  18.0   Ludhiana    Student                3.0
# 27370  137980  Female  18.0  Hyderabad    Student                5.0
# 5226    26400    Male  18.0       Agra    Student                2.0
# 5224    26392    Male  18.0    Kolkata    Student                5.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 9100             0.0  9.19                 3.0               0.0
# 9867             0.0  8.70                 5.0               0.0
# 27370            0.0  6.16                 4.0               0.0
# 5226             0.0  6.53                 4.0               0.0
# 5224             0.0  9.98                 4.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 9100   Less than 5 hours      Unhealthy  Class 12
# 9867   More than 8 hours       Moderate  Class 12
# ...

# %%
#minimun and maximum value in a column
ds['Age'].min()
# Out:
# 18.0

# %%
ds['Age'].max()
# Out:
# 59.0

# %%
#find unique values
ds['City'].unique()
# Out:
# array(['Visakhapatnam', 'Bangalore', 'Srinagar', 'Varanasi', 'Jaipur',
#        'Pune', 'Thane', 'Chennai', 'Nagpur', 'Nashik', 'Vadodara',
#        'Kalyan', 'Rajkot', 'Ahmedabad', 'Kolkata', 'Mumbai', 'Lucknow',
#        'Indore', 'Surat', 'Ludhiana', 'Bhopal', 'Meerut', 'Agra',
#        'Ghaziabad', 'Hyderabad', 'Vasai-Virar', 'Kanpur', 'Patna',
#        'Faridabad', 'Delhi', 'Saanvi', 'M.Tech', 'Bhavna', 'Less Delhi',
#        'City', '3.0', 'Less than 5 Kalyan', 'Mira', 'Harsha', 'Vaanya',
#        'Gaurav', 'Harsh', 'Reyansh', 'Kibara', 'Rashi', 'ME', 'M.Com',
#        'Nalyan', 'Mihir', 'Nalini', 'Nandini', 'Khaziabad'], dtype=object)

# %%
ds['City'].nunique()
# Out:
# 52

# %%
#filter the rows where the person has sucidal thoughts
ds[ds['Have you ever had suicidal thoughts ?']=='Yes']
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# 8          59    Male  28.0         Nagpur    Student                3.0
# 9          62    Male  31.0         Nashik    Student                2.0
# ...       ...     ...   ...            ...        ...                ...
# 27894  140681    Male  23.0       Srinagar    Student                3.0
# 27895  140684    Male  31.0        Lucknow    Student                2.0
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
ds.query("`Have you ever had suicidal thoughts ?` == 'Yes'")
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# 8          59    Male  28.0         Nagpur    Student                3.0
# 9          62    Male  31.0         Nashik    Student                2.0
# ...       ...     ...   ...            ...        ...                ...
# 27894  140681    Male  23.0       Srinagar    Student                3.0
# 27895  140684    Male  31.0        Lucknow    Student                2.0
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
#filter for high financial stress
ds[ds['Financial Stress']>2.0]
# Out:
#            id  Gender   Age      City Profession  Academic Pressure  \
# 3          30  Female  28.0  Varanasi    Student                3.0
# 8          59    Male  28.0    Nagpur    Student                3.0
# 9          62    Male  31.0    Nashik    Student                2.0
# 14        103  Female  19.0    Kalyan    Student                5.0
# 16        120    Male  25.0    Nashik    Student                5.0
# ...       ...     ...   ...       ...        ...                ...
# 27891  140645  Female  28.0     Thane    Student                4.0
# 27894  140681    Male  23.0  Srinagar    Student                3.0
# 27897  140686    Male  27.0  Ludhiana    Student                2.0
# 27899  140690  Female  18.0  Ludhiana    Student                5.0
# 27900  140699    Male  27.0     Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 3                0.0  5.59                 2.0               0.0
# ...

# %%
ds['Have you ever had suicidal thoughts ?'].map({"Yes":1,"No":0})
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 27896    1
# 27897    0
# 27898    0
# 27899    1
# 27900    1
# Name: Have you ever had suicidal thoughts ?, Length: 27901, dtype: int64

# %%
#mental health

# %%
ds[['Have you ever had suicidal thoughts ?','Family History of Mental Illness']].replace({"Yes":1,"No":0})
# Out:
# C:\Users\KALPESH TALESHA\AppData\Local\Temp\ipykernel_66580\3964563434.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ds[['Have you ever had suicidal thoughts ?','Family History of Mental Illness']].replace({"Yes":1,"No":0})
#        Have you ever had suicidal thoughts ?  Family History of Mental Illness
# 0                                          1                                 0
# 1                                          0                                 1
# 2                                          0                                 1
# 3                                          1                                 1
# 4                                          1                                 0
# ...

# %%
#select the element in the first row and first column
ds.iloc[0,1]
# Out:
# 'Male'

# %%
ds.iloc[0,0]
# Out:
# 2

# %%
#find all rows where gender is male and depression is 1
ds[(ds['Gender']=='Male')&(ds['Depression']==1)]
# Out:
#            id Gender   Age           City Profession  Academic Pressure  \
# 0           2   Male  33.0  Visakhapatnam    Student                5.0
# 8          59   Male  28.0         Nagpur    Student                3.0
# 9          62   Male  31.0         Nashik    Student                2.0
# 10         83   Male  24.0         Nagpur    Student                3.0
# 12         94   Male  27.0         Kalyan    Student                5.0
# ...       ...    ...   ...            ...        ...                ...
# 27881  140564   Male  27.0          Surat    Student                4.0
# 27884  140594   Male  18.0         Meerut    Student                5.0
# 27887  140624   Male  32.0         Rajkot    Student                4.0
# 27888  140630   Male  19.0        Kolkata    Student                4.0
# 27900  140699   Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
#select the first 3 rows of the age and cgpa column
ds.loc[0:2,['Age','CGPA']]
# Out:
#     Age  CGPA
# 0  33.0  8.97
# 1  24.0  5.90
# 2  31.0  7.03

# %%
#change the sleep duration for the person with id =1 to 8 to 9 hour
if(ds['id']==1).any():
    ds.loc[ds['id']==1,'Sleep Duration']="8-9 hours"
    print(ds.loc[ds['id']==1])
else:
    print("No row with id == 1 found")
# Out:
# No row with id == 1 found

# %%
ds.loc[ds['id']==2,'Sleep Duration']= "8-9 hours"
print(ds.loc[ds['id']==2])
# Out:
#    id Gender   Age           City Profession  Academic Pressure  \
# 0   2   Male  33.0  Visakhapatnam    Student                5.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction Sleep Duration  \
# 0            0.0  8.97                 2.0               0.0      8-9 hours
#
#   Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# 0        Healthy  B.Pharm                                   Yes
#
#    Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 0               3.0               1.0                               No
#
#    Depression
# 0           1

# %%
#print the first and fifth row along with second column
ds.iloc[[0,5],1]
# Out:
# 0    Male
# 5    Male
# Name: Gender, dtype: object

# %%
#
ds.loc[[0,4],'Degree']
# Out:
# 0    B.Pharm
# 4     M.Tech
# Name: Degree, dtype: object

# %%
ds['City'].value_counts()
# Out:
# City
# Kalyan                1570
# Srinagar              1372
# Hyderabad             1340
# Vasai-Virar           1290
# Lucknow               1155
# Thane                 1139
# Ludhiana              1111
# Agra                  1094
# Surat                 1078
# Kolkata               1066
# Jaipur                1036
# Patna                 1007
# Visakhapatnam          969
# Pune                   968
# Ahmedabad              951
# Bhopal                 934
# Chennai                885
# Meerut                 825
# Rajkot                 816
# Delhi                  768
# Bangalore              767
# Ghaziabad              745
# Mumbai                 699
# Vadodara               694
# Varanasi               685
# Nagpur                 651
# Indore                 643
# Kanpur                 609
# Nashik                 547
# Faridabad              461
# Saanvi                   2
# Bhavna                   2
# City                     2
# Harsha                   2
# ...

# %%
#select 2 columns degree , sleep duration start with 1 and end on 18 and skip 2
ds.loc[1:18:2,['Degree','Sleep Duration']]
# Out:
#       Degree     Sleep Duration
# 1        BSc          5-6 hours
# 3        BCA          7-8 hours
# 5        PhD  Less than 5 hours
# 7   Class 12  Less than 5 hours
# 9        LLB  Less than 5 hours
# 11        BE  Less than 5 hours
# 13  Class 12  Less than 5 hours
# 15    M.Tech  More than 8 hours
# 17  Class 12          5-6 hours

# %%
ds.loc[1:18:2,'City':'CGPA']
# Out:
#          City Profession  Academic Pressure  Work Pressure  CGPA
# 1   Bangalore    Student                2.0            0.0  5.90
# 3    Varanasi    Student                3.0            0.0  5.59
# 5        Pune    Student                2.0            0.0  5.70
# 7     Chennai    Student                2.0            0.0  8.04
# 9      Nashik    Student                2.0            0.0  8.38
# 11   Vadodara    Student                3.0            0.0  7.03
# 13     Rajkot    Student                2.0            0.0  8.52
# 15   Srinagar    Student                3.0            0.0  8.58
# 17  Ahmedabad    Student                5.0            0.0  7.25

# %%
#write a code to filter a dataset and select rows where the city column is Kalyan, jaipur, delhi and then select only financial stress column from the filtered rows

# %%
ds[ds['City'].isin(['Kalyan', 'Jaipur', 'Delhi'])][['Financial Stress']]
# Out:
#        Financial Stress
# 4                   1.0
# 12                  1.0
# 14                  5.0
# 19                  3.0
# 29                  2.0
# ...                 ...
# 27854               1.0
# 27860               1.0
# 27872               4.0
# 27879               3.0
# 27886               3.0
#
# [3374 rows x 1 columns]
