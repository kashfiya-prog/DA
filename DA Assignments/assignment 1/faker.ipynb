# %%
pip install faker
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install faker --no-warn-script-location

# %%
import random

# %%
import faker

# %%
import pandas as pd

# %%
fake = faker.Faker()

# %%
data = {
    "First Name": ["Aarav","Isha","Mohammad","Zoya","Ayaan"],
    "Last Name": ["Sharma","Patel","Khan","Shaikh","Ansari"],
    "Email ID": [fake.email() for _ in range(5)],
    "Age": [random.randint(18,35) for _ in range(5)]
}

# %%
data
# Out:
# {'First Name': ['Aarav', 'Isha', 'Mohammad', 'Zoya', 'Ayaan'],
#  'Last Name': ['Sharma', 'Patel', 'Khan', 'Shaikh', 'Ansari'],
#  'Email ID': ['lindseybarker@example.net',
#   'jacksonshawn@example.com',
#   'achan@example.org',
#   'james70@example.org',
#   'ocherry@example.org'],
#  'Age': [34, 25, 18, 29, 18]}

# %%
pd.DataFrame(data)
# Out:
#   First Name Last Name                   Email ID  Age
# 0      Aarav    Sharma  lindseybarker@example.net   34
# 1       Isha     Patel   jacksonshawn@example.com   25
# 2   Mohammad      Khan          achan@example.org   18
# 3       Zoya    Shaikh        james70@example.org   29
# 4      Ayaan    Ansari        ocherry@example.org   18

# %%
print(fake.name())
# Out:
# Craig Pearson

# %%
print(fake.address())
# Out:
# 559 Suarez Trail Suite 151
# East John, GU 96162

# %%
print(fake.phone_number())
# Out:
# 001-304-433-7297x041

# %%
data = []
for _ in range(10):
    record = {
        "Name" : fake.name(),
        "Address" : fake.address(),
        "Email" : fake.email(),
        "Date of Birth" : fake.date_of_birth(),
        "Phone Number" : fake.phone_number(),
        "Company" : fake.company()
    }
    data.append(record)

# %%
data
# Out:
# [{'Name': 'Chatura Dora',
#   'Address': '764\nBarad Nagar\nMoradabad-723667',
#   'Email': 'fnori@example.org',
#   'Date of Birth': datetime.date(1925, 3, 15),
#   'Phone Number': '+911745189934',
#   'Company': 'Pau and Sons'},
#  {'Name': 'Girik Kurian',
#   'Address': '59\nDar Chowk\nUnnao-278719',
#   'Email': 'yauvanivaidya@example.com',
#   'Date of Birth': datetime.date(1984, 1, 16),
#   'Phone Number': '7540007899',
#   'Company': 'Acharya, Badal and Lanka'},
#  {'Name': 'Anvi Bhatti',
#   'Address': 'H.No. 15\nVarma Street, Tiruppur 634028',
#   'Email': 'voak@example.org',
#   'Date of Birth': datetime.date(1917, 10, 6),
#   'Phone Number': '7962538917',
#   'Company': 'Vasa PLC'},
#  {'Name': 'Yashvi Hayer',
#   'Address': 'H.No. 83, Mammen Path, Kolkata-069479',
#   'Email': 'adwetanigam@example.net',
#   'Date of Birth': datetime.date(1968, 4, 17),
#   'Phone Number': '+919252745367',
#   'Company': 'Ramesh, Chakrabarti and Vala'},
#  {'Name': 'Ojasvi Swamy',
# ...

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                  Name                                         Address  \
# 0        Chatura Dora              764\nBarad Nagar\nMoradabad-723667
# 1        Girik Kurian                     59\nDar Chowk\nUnnao-278719
# 2         Anvi Bhatti         H.No. 15\nVarma Street, Tiruppur 634028
# 3        Yashvi Hayer           H.No. 83, Mammen Path, Kolkata-069479
# 4        Ojasvi Swamy                   19, Wali Nagar\nKadapa-184798
# 5  Vyanjana Chaudhary              H.No. 294, Roy Road, Hospet 664738
# 6        Nihal Taneja        H.No. 10\nDhillon Circle, Dhanbad-109899
# 7       Laksh Dhillon  H.No. 77\nBalakrishnan Street\nBareilly 521896
# 8           Diya Arya             64/207\nSaxena Street\nNoida 539844
# 9     Pallavi Mohanty         972, Mohanty Street\nMuzaffarpur 764595
#
#                          Email Date of Birth   Phone Number  \
# 0            fnori@example.org    1925-03-15  +911745189934
# 1    yauvanivaidya@example.com    1984-01-16     7540007899
# ...

# %%
fake= faker.Faker('en_IN')

# %%
print(fake.name())
# Out:
# Barkha Modi

# %%
df.columns
# Out:
# Index(['Name', 'Address', 'Email', 'Date of Birth', 'Phone Number', 'Company'], dtype='object')

# %%
df.rename(columns={df.columns[0]:"Full Name"}, inplace=True)

# %%
df
# Out:
#             Full Name                                         Address  \
# 0        Chatura Dora              764\nBarad Nagar\nMoradabad-723667
# 1        Girik Kurian                     59\nDar Chowk\nUnnao-278719
# 2         Anvi Bhatti         H.No. 15\nVarma Street, Tiruppur 634028
# 3        Yashvi Hayer           H.No. 83, Mammen Path, Kolkata-069479
# 4        Ojasvi Swamy                   19, Wali Nagar\nKadapa-184798
# 5  Vyanjana Chaudhary              H.No. 294, Roy Road, Hospet 664738
# 6        Nihal Taneja        H.No. 10\nDhillon Circle, Dhanbad-109899
# 7       Laksh Dhillon  H.No. 77\nBalakrishnan Street\nBareilly 521896
# 8           Diya Arya             64/207\nSaxena Street\nNoida 539844
# 9     Pallavi Mohanty         972, Mohanty Street\nMuzaffarpur 764595
#
#                          Email Date of Birth   Phone Number  \
# 0            fnori@example.org    1925-03-15  +911745189934
# 1    yauvanivaidya@example.com    1984-01-16     7540007899
# ...

# %%
df.rename(columns={
    "Phone Number": "Contact Number",
    "Email": "Email Address"
}, inplace=True)

# %%
df
# Out:
#             Full Name                                         Address  \
# 0        Chatura Dora              764\nBarad Nagar\nMoradabad-723667
# 1        Girik Kurian                     59\nDar Chowk\nUnnao-278719
# 2         Anvi Bhatti         H.No. 15\nVarma Street, Tiruppur 634028
# 3        Yashvi Hayer           H.No. 83, Mammen Path, Kolkata-069479
# 4        Ojasvi Swamy                   19, Wali Nagar\nKadapa-184798
# 5  Vyanjana Chaudhary              H.No. 294, Roy Road, Hospet 664738
# 6        Nihal Taneja        H.No. 10\nDhillon Circle, Dhanbad-109899
# 7       Laksh Dhillon  H.No. 77\nBalakrishnan Street\nBareilly 521896
# 8           Diya Arya             64/207\nSaxena Street\nNoida 539844
# 9     Pallavi Mohanty         972, Mohanty Street\nMuzaffarpur 764595
#
#                  Email Address Date of Birth Contact Number  \
# 0            fnori@example.org    1925-03-15  +911745189934
# 1    yauvanivaidya@example.com    1984-01-16     7540007899
# ...

# %%
[x.upper() for x in df.columns]
# Out:
# ['FULL NAME',
#  'ADDRESS',
#  'EMAIL ADDRESS',
#  'DATE OF BIRTH',
#  'CONTACT NUMBER',
#  'COMPANY']

# %%
[x.lower() for x in df.columns]
# Out:
# ['full name',
#  'address',
#  'email address',
#  'date of birth',
#  'contact number',
#  'company']

# %%
df
# Out:
#             Full Name                                         Address  \
# 0        Chatura Dora              764\nBarad Nagar\nMoradabad-723667
# 1        Girik Kurian                     59\nDar Chowk\nUnnao-278719
# 2         Anvi Bhatti         H.No. 15\nVarma Street, Tiruppur 634028
# 3        Yashvi Hayer           H.No. 83, Mammen Path, Kolkata-069479
# 4        Ojasvi Swamy                   19, Wali Nagar\nKadapa-184798
# 5  Vyanjana Chaudhary              H.No. 294, Roy Road, Hospet 664738
# 6        Nihal Taneja        H.No. 10\nDhillon Circle, Dhanbad-109899
# 7       Laksh Dhillon  H.No. 77\nBalakrishnan Street\nBareilly 521896
# 8           Diya Arya             64/207\nSaxena Street\nNoida 539844
# 9     Pallavi Mohanty         972, Mohanty Street\nMuzaffarpur 764595
#
#                  Email Address Date of Birth Contact Number  \
# 0            fnori@example.org    1925-03-15  +911745189934
# 1    yauvanivaidya@example.com    1984-01-16     7540007899
# ...

# %%
df.columns.str.replace(" ","_")
# Out:
# Index(['Full_Name', 'Address', 'Email_Address', 'Date_of_Birth',
#        'Contact_Number', 'Company'],
#       dtype='object')

# %%
df
# Out:
#             Full Name                                         Address  \
# 0        Chatura Dora              764\nBarad Nagar\nMoradabad-723667
# 1        Girik Kurian                     59\nDar Chowk\nUnnao-278719
# 2         Anvi Bhatti         H.No. 15\nVarma Street, Tiruppur 634028
# 3        Yashvi Hayer           H.No. 83, Mammen Path, Kolkata-069479
# 4        Ojasvi Swamy                   19, Wali Nagar\nKadapa-184798
# 5  Vyanjana Chaudhary              H.No. 294, Roy Road, Hospet 664738
# 6        Nihal Taneja        H.No. 10\nDhillon Circle, Dhanbad-109899
# 7       Laksh Dhillon  H.No. 77\nBalakrishnan Street\nBareilly 521896
# 8           Diya Arya             64/207\nSaxena Street\nNoida 539844
# 9     Pallavi Mohanty         972, Mohanty Street\nMuzaffarpur 764595
#
#                  Email Address Date of Birth Contact Number  \
# 0            fnori@example.org    1925-03-15  +911745189934
# 1    yauvanivaidya@example.com    1984-01-16     7540007899
# ...

# %%
df.loc[2] = ["Kalpesh","Mumbai", "kalpesh@gmail.com","1stMar2004","7208495230","BFC"]

# %%
df
# Out:
#             Full Name                                         Address  \
# 0        Chatura Dora              764\nBarad Nagar\nMoradabad-723667
# 1        Girik Kurian                     59\nDar Chowk\nUnnao-278719
# 2             Kalpesh                                          Mumbai
# 3        Yashvi Hayer           H.No. 83, Mammen Path, Kolkata-069479
# 4        Ojasvi Swamy                   19, Wali Nagar\nKadapa-184798
# 5  Vyanjana Chaudhary              H.No. 294, Roy Road, Hospet 664738
# 6        Nihal Taneja        H.No. 10\nDhillon Circle, Dhanbad-109899
# 7       Laksh Dhillon  H.No. 77\nBalakrishnan Street\nBareilly 521896
# 8           Diya Arya             64/207\nSaxena Street\nNoida 539844
# 9     Pallavi Mohanty         972, Mohanty Street\nMuzaffarpur 764595
#
#                  Email Address Date of Birth Contact Number  \
# 0            fnori@example.org    1925-03-15  +911745189934
# 1    yauvanivaidya@example.com    1984-01-16     7540007899
# ...

# %%
df.loc[2,["Address"]]=["New Mumbai"]

# %%
df
# Out:
#             Full Name                                         Address  \
# 0        Chatura Dora              764\nBarad Nagar\nMoradabad-723667
# 1        Girik Kurian                     59\nDar Chowk\nUnnao-278719
# 2             Kalpesh                                      New Mumbai
# 3        Yashvi Hayer           H.No. 83, Mammen Path, Kolkata-069479
# 4        Ojasvi Swamy                   19, Wali Nagar\nKadapa-184798
# 5  Vyanjana Chaudhary              H.No. 294, Roy Road, Hospet 664738
# 6        Nihal Taneja        H.No. 10\nDhillon Circle, Dhanbad-109899
# 7       Laksh Dhillon  H.No. 77\nBalakrishnan Street\nBareilly 521896
# 8           Diya Arya             64/207\nSaxena Street\nNoida 539844
# 9     Pallavi Mohanty         972, Mohanty Street\nMuzaffarpur 764595
#
#                  Email Address Date of Birth Contact Number  \
# 0            fnori@example.org    1925-03-15  +911745189934
# 1    yauvanivaidya@example.com    1984-01-16     7540007899
# ...

# %%
df["Address"].apply(len)
# Out:
# 0    32
# 1    25
# 2    10
# 3    37
# 4    28
# 5    34
# 6    39
# 7    44
# 8    33
# 9    38
# Name: Address, dtype: int64

# %%
df.apply(len)
# Out:
# Full Name         10
# Address           10
# Email Address     10
# Date of Birth     10
# Contact Number    10
# Company           10
# dtype: int64

# %%
len(df["Address"])
# Out:
# 10

# %%
df.apply(len, axis="columns")
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# 5    6
# 6    6
# 7    6
# 8    6
# 9    6
# dtype: int64

# %%
def update_email(Email):
    return Email.upper()
df["Email Address"].apply(update_email)
# Out:
# 0              FNORI@EXAMPLE.ORG
# 1      YAUVANIVAIDYA@EXAMPLE.COM
# 2              KALPESH@GMAIL.COM
# 3        ADWETANIGAM@EXAMPLE.NET
# 4         EKAVIRKADE@EXAMPLE.ORG
# 5         NANDAKAMYA@EXAMPLE.ORG
# 6            DPILLAY@EXAMPLE.NET
# 7    NARANGNATHANIEL@EXAMPLE.ORG
# 8         BAHRIUDANT@EXAMPLE.ORG
# 9           ARYADIYA@EXAMPLE.NET
# Name: Email Address, dtype: object

# %%
df
# Out:
#             Full Name                                         Address  \
# 0        Chatura Dora              764\nBarad Nagar\nMoradabad-723667
# 1        Girik Kurian                     59\nDar Chowk\nUnnao-278719
# 2             Kalpesh                                      New Mumbai
# 3        Yashvi Hayer           H.No. 83, Mammen Path, Kolkata-069479
# 4        Ojasvi Swamy                   19, Wali Nagar\nKadapa-184798
# 5  Vyanjana Chaudhary              H.No. 294, Roy Road, Hospet 664738
# 6        Nihal Taneja        H.No. 10\nDhillon Circle, Dhanbad-109899
# 7       Laksh Dhillon  H.No. 77\nBalakrishnan Street\nBareilly 521896
# 8           Diya Arya             64/207\nSaxena Street\nNoida 539844
# 9     Pallavi Mohanty         972, Mohanty Street\nMuzaffarpur 764595
#
#                  Email Address Date of Birth Contact Number  \
# 0            fnori@example.org    1925-03-15  +911745189934
# 1    yauvanivaidya@example.com    1984-01-16     7540007899
# ...

# %%
df["Email Address"]= df["Email Address"].str.upper()

# %%
df
# Out:
#             Full Name                                         Address  \
# 0        Chatura Dora              764\nBarad Nagar\nMoradabad-723667
# 1        Girik Kurian                     59\nDar Chowk\nUnnao-278719
# 2             Kalpesh                                      New Mumbai
# 3        Yashvi Hayer           H.No. 83, Mammen Path, Kolkata-069479
# 4        Ojasvi Swamy                   19, Wali Nagar\nKadapa-184798
# 5  Vyanjana Chaudhary              H.No. 294, Roy Road, Hospet 664738
# 6        Nihal Taneja        H.No. 10\nDhillon Circle, Dhanbad-109899
# 7       Laksh Dhillon  H.No. 77\nBalakrishnan Street\nBareilly 521896
# 8           Diya Arya             64/207\nSaxena Street\nNoida 539844
# 9     Pallavi Mohanty         972, Mohanty Street\nMuzaffarpur 764595
#
#                  Email Address Date of Birth Contact Number  \
# 0            FNORI@EXAMPLE.ORG    1925-03-15  +911745189934
# 1    YAUVANIVAIDYA@EXAMPLE.COM    1984-01-16     7540007899
# ...

# %%
df["Email Address"]= df["Email Address"].apply(lambda x: x.lower())

# %%
df
# Out:
#             Full Name                                         Address  \
# 0        Chatura Dora              764\nBarad Nagar\nMoradabad-723667
# 1        Girik Kurian                     59\nDar Chowk\nUnnao-278719
# 2             Kalpesh                                      New Mumbai
# 3        Yashvi Hayer           H.No. 83, Mammen Path, Kolkata-069479
# 4        Ojasvi Swamy                   19, Wali Nagar\nKadapa-184798
# 5  Vyanjana Chaudhary              H.No. 294, Roy Road, Hospet 664738
# 6        Nihal Taneja        H.No. 10\nDhillon Circle, Dhanbad-109899
# 7       Laksh Dhillon  H.No. 77\nBalakrishnan Street\nBareilly 521896
# 8           Diya Arya             64/207\nSaxena Street\nNoida 539844
# 9     Pallavi Mohanty         972, Mohanty Street\nMuzaffarpur 764595
#
#                  Email Address Date of Birth Contact Number  \
# 0            fnori@example.org    1925-03-15  +911745189934
# 1    yauvanivaidya@example.com    1984-01-16     7540007899
# ...

# %%
df[["Full Name","Company"]].applymap(len)
# Out:
# C:\Users\KALPESH TALESHA\AppData\Local\Temp\ipykernel_40064\1483338795.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[["Full Name","Company"]].applymap(len)
#    Full Name  Company
# 0         12       12
# 1         12       24
# 2          7        3
# 3         12       28
# 4         12       12
# 5         18        9
# 6         12       21
# 7         13       29
# 8          9        9
# 9         15       12

# %%
df["Full Name"]+' '+ df["Email Address"]
# Out:
# 0               Chatura Dora fnori@example.org
# 1       Girik Kurian yauvanivaidya@example.com
# 2                    Kalpesh kalpesh@gmail.com
# 3         Yashvi Hayer adwetanigam@example.net
# 4          Ojasvi Swamy ekavirkade@example.org
# 5    Vyanjana Chaudhary nandakamya@example.org
# 6             Nihal Taneja dpillay@example.net
# 7    Laksh Dhillon narangnathaniel@example.org
# 8             Diya Arya bahriudant@example.org
# 9         Pallavi Mohanty aryadiya@example.net
# dtype: object

# %%
df["Details"]= df["Full Name"]+' '+ df["Email Address"]

# %%
df
# Out:
#             Full Name                                         Address  \
# 0        Chatura Dora              764\nBarad Nagar\nMoradabad-723667
# 1        Girik Kurian                     59\nDar Chowk\nUnnao-278719
# 2             Kalpesh                                      New Mumbai
# 3        Yashvi Hayer           H.No. 83, Mammen Path, Kolkata-069479
# 4        Ojasvi Swamy                   19, Wali Nagar\nKadapa-184798
# 5  Vyanjana Chaudhary              H.No. 294, Roy Road, Hospet 664738
# 6        Nihal Taneja        H.No. 10\nDhillon Circle, Dhanbad-109899
# 7       Laksh Dhillon  H.No. 77\nBalakrishnan Street\nBareilly 521896
# 8           Diya Arya             64/207\nSaxena Street\nNoida 539844
# 9     Pallavi Mohanty         972, Mohanty Street\nMuzaffarpur 764595
#
#                  Email Address Date of Birth Contact Number  \
# 0            fnori@example.org    1925-03-15  +911745189934
# 1    yauvanivaidya@example.com    1984-01-16     7540007899
# ...

# %%
df.drop(columns= "Details")
# Out:
#             Full Name                                         Address  \
# 0        Chatura Dora              764\nBarad Nagar\nMoradabad-723667
# 1        Girik Kurian                     59\nDar Chowk\nUnnao-278719
# 2             Kalpesh                                      New Mumbai
# 3        Yashvi Hayer           H.No. 83, Mammen Path, Kolkata-069479
# 4        Ojasvi Swamy                   19, Wali Nagar\nKadapa-184798
# 5  Vyanjana Chaudhary              H.No. 294, Roy Road, Hospet 664738
# 6        Nihal Taneja        H.No. 10\nDhillon Circle, Dhanbad-109899
# 7       Laksh Dhillon  H.No. 77\nBalakrishnan Street\nBareilly 521896
# 8           Diya Arya             64/207\nSaxena Street\nNoida 539844
# 9     Pallavi Mohanty         972, Mohanty Street\nMuzaffarpur 764595
#
#                  Email Address Date of Birth Contact Number  \
# 0            fnori@example.org    1925-03-15  +911745189934
# 1    yauvanivaidya@example.com    1984-01-16     7540007899
# ...

# %%
df["Details"]= df["Full Name"]+' '+ df["Email Address"]

# %%
df
# Out:
#             Full Name                                         Address  \
# 0        Chatura Dora              764\nBarad Nagar\nMoradabad-723667
# 1        Girik Kurian                     59\nDar Chowk\nUnnao-278719
# 2             Kalpesh                                      New Mumbai
# 3        Yashvi Hayer           H.No. 83, Mammen Path, Kolkata-069479
# 4        Ojasvi Swamy                   19, Wali Nagar\nKadapa-184798
# 5  Vyanjana Chaudhary              H.No. 294, Roy Road, Hospet 664738
# 6        Nihal Taneja        H.No. 10\nDhillon Circle, Dhanbad-109899
# 7       Laksh Dhillon  H.No. 77\nBalakrishnan Street\nBareilly 521896
# 8           Diya Arya             64/207\nSaxena Street\nNoida 539844
# 9     Pallavi Mohanty         972, Mohanty Street\nMuzaffarpur 764595
#
#                  Email Address Date of Birth Contact Number  \
# 0            fnori@example.org    1925-03-15  +911745189934
# 1    yauvanivaidya@example.com    1984-01-16     7540007899
# ...

# %%
df["Details"].str.split(" ", expand= True)
# Out:
#           0                  1                            2
# 0   Chatura               Dora            fnori@example.org
# 1     Girik             Kurian    yauvanivaidya@example.com
# 2   Kalpesh  kalpesh@gmail.com                         None
# 3    Yashvi              Hayer      adwetanigam@example.net
# 4    Ojasvi              Swamy       ekavirkade@example.org
# 5  Vyanjana          Chaudhary       nandakamya@example.org
# 6     Nihal             Taneja          dpillay@example.net
# 7     Laksh            Dhillon  narangnathaniel@example.org
# 8      Diya               Arya       bahriudant@example.org
# 9   Pallavi            Mohanty         aryadiya@example.net

# %%
ds= pd.read_csv("faker_csv.csv")

# %%
ds
# Out:
#   First Name    Surname  Age       City        Hobby             Bank Name  \
# 0        Raj     Sharma   28     Mumbai      Cricket   State Bank of India
# 1      Priya       Iyer   24    Chennai     Painting             HDFC Bank
# 2      Ankit      Verma   32      Delhi      Reading            ICICI Bank
# 3      Sneha      Patil   27       Pune      Dancing             Axis Bank
# 4     Vikram      Singh   35     Jaipur     Trekking  Punjab National Bank
# 5       Ritu  Choudhary   26     Bhopal      Cooking   Kotak Mahindra Bank
# 6      Karan      Mehta   30  Ahmedabad  Photography        Bank of Baroda
# 7      Aisha       Khan   22  Hyderabad      Singing           Canara Bank
# 8     Manish      Joshi   29  Bangalore        Chess              Yes Bank
# 9       Neha     Kapoor   25    Kolkata    Traveling         IndusInd Bank
#
#    Gender
# 0    Male
# 1  Female
# 2    Male
# 3  Female
# 4    Male
# 5  Female
# 6    Male
# 7  Female
# 8    Male
# 9  Female

# %%
ds.sort_values(by = 'Surname')
# Out:
#   First Name    Surname  Age       City        Hobby             Bank Name  \
# 5       Ritu  Choudhary   26     Bhopal      Cooking   Kotak Mahindra Bank
# 1      Priya       Iyer   24    Chennai     Painting             HDFC Bank
# 8     Manish      Joshi   29  Bangalore        Chess              Yes Bank
# 9       Neha     Kapoor   25    Kolkata    Traveling         IndusInd Bank
# 7      Aisha       Khan   22  Hyderabad      Singing           Canara Bank
# 6      Karan      Mehta   30  Ahmedabad  Photography        Bank of Baroda
# 3      Sneha      Patil   27       Pune      Dancing             Axis Bank
# 0        Raj     Sharma   28     Mumbai      Cricket   State Bank of India
# 4     Vikram      Singh   35     Jaipur     Trekking  Punjab National Bank
# 2      Ankit      Verma   32      Delhi      Reading            ICICI Bank
#
#    Gender
# 5  Female
# 1  Female
# 8    Male
# 9  Female
# 7  Female
# 6    Male
# 3  Female
# 0    Male
# 4    Male
# 2    Male

# %%
ds.sort_values(by = ['Hobby','City'])
# Out:
#   First Name    Surname  Age       City        Hobby             Bank Name  \
# 8     Manish      Joshi   29  Bangalore        Chess              Yes Bank
# 5       Ritu  Choudhary   26     Bhopal      Cooking   Kotak Mahindra Bank
# 0        Raj     Sharma   28     Mumbai      Cricket   State Bank of India
# 3      Sneha      Patil   27       Pune      Dancing             Axis Bank
# 1      Priya       Iyer   24    Chennai     Painting             HDFC Bank
# 6      Karan      Mehta   30  Ahmedabad  Photography        Bank of Baroda
# 2      Ankit      Verma   32      Delhi      Reading            ICICI Bank
# 7      Aisha       Khan   22  Hyderabad      Singing           Canara Bank
# 9       Neha     Kapoor   25    Kolkata    Traveling         IndusInd Bank
# 4     Vikram      Singh   35     Jaipur     Trekking  Punjab National Bank
#
#    Gender
# 8    Male
# 5  Female
# 0    Male
# 3  Female
# 1  Female
# 6    Male
# 2    Male
# 7  Female
# 9  Female
# 4    Male

# %%
ds["Age"].nlargest(3)
# Out:
# 4    35
# 2    32
# 6    30
# Name: Age, dtype: int64

# %%
ds.groupby('Gender')['Age'].mean()
# Out:
# Gender
# Female    24.8
# Male      30.8
# Name: Age, dtype: float64

# %%
ds.groupby("City")["First Name"].count()
# Out:
# City
# Ahmedabad    1
# Bangalore    1
# Bhopal       1
# Chennai      1
# Delhi        1
# Hyderabad    1
# Jaipur       1
# Kolkata      1
# Mumbai       1
# Pune         1
# Name: First Name, dtype: int64

# %%
ds.groupby(["Gender","Hobby"])["Age"].mean()
# Out:
# Gender  Hobby
# Female  Cooking        26.0
#         Dancing        27.0
#         Painting       24.0
#         Singing        22.0
#         Traveling      25.0
# Male    Chess          29.0
#         Cricket        28.0
#         Photography    30.0
#         Reading        32.0
#         Trekking       35.0
# Name: Age, dtype: float64

# %%
ds.groupby(["Gender","Hobby"])["Age"].sum()
# Out:
# Gender  Hobby
# Female  Cooking        26
#         Dancing        27
#         Painting       24
#         Singing        22
#         Traveling      25
# Male    Chess          29
#         Cricket        28
#         Photography    30
#         Reading        32
#         Trekking       35
# Name: Age, dtype: int64

# %%
ds.groupby(["Gender","Hobby"])["Age"].max()
# Out:
# Gender  Hobby
# Female  Cooking        26
#         Dancing        27
#         Painting       24
#         Singing        22
#         Traveling      25
# Male    Chess          29
#         Cricket        28
#         Photography    30
#         Reading        32
#         Trekking       35
# Name: Age, dtype: int64

# %%
ds.groupby(["Gender","Hobby"])["Age"].min()
# Out:
# Gender  Hobby
# Female  Cooking        26
#         Dancing        27
#         Painting       24
#         Singing        22
#         Traveling      25
# Male    Chess          29
#         Cricket        28
#         Photography    30
#         Reading        32
#         Trekking       35
# Name: Age, dtype: int64

# %%
ds.groupby("Gender").agg({
    "Age": ["mean","sum"],
    "Hobby": "count",
    "Bank Name": "nunique"
})
# Out:
#          Age      Hobby Bank Name
#         mean  sum count   nunique
# Gender
# Female  24.8  124     5         5
# Male    30.8  154     5         5

# %%
filt = ds["City"]!="Mumbai"
ds.loc[filt]["Hobby"].value_counts()
# Out:
# Hobby
# Painting       1
# Reading        1
# Dancing        1
# Trekking       1
# Cooking        1
# Photography    1
# Singing        1
# Chess          1
# Traveling      1
# Name: count, dtype: int64

# %%
filt = ds["City"]=="Mumbai"
ds.loc[filt]["Hobby"].value_counts()
# Out:
# Hobby
# Cricket    1
# Name: count, dtype: int64

# %%
filt = ds["Age"] < 30
ds.loc[filt]["City"].str.contains("Mumbai").sum()
# Out:
# 1

# %%
#using lambda
ds.loc[filt]["City"].apply(lambda x: "Mumbai" in str(x)).sum()
# Out:
# 1
