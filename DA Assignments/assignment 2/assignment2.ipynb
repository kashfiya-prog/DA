# %%
import pandas as pd

# %%
ds= pd.read_csv("StudentsPerformance.csv")

# %%
ds
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
ds.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
ds.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
ds.shape
# Out:
# (1000, 8)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
ds.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
ds['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
ds[['gender','race/ethnicity']]
# Out:
#      gender race/ethnicity
# 0    female        group B
# 1    female        group C
# 2    female        group B
# 3      male        group A
# 4      male        group C
# ..      ...            ...
# 995  female        group E
# 996    male        group C
# 997  female        group C
# 998  female        group D
# 999  female        group D
#
# [1000 rows x 2 columns]

# %%
ds.iloc[0]
# Out:
# gender                                    female
# race/ethnicity                           group B
# parental level of education    bachelor's degree
# lunch                                   standard
# test preparation course                     none
# math score                                    72
# reading score                                 72
# writing score                                 74
# Name: 0, dtype: object

# %%
ds.loc[0]
# Out:
# gender                                    female
# race/ethnicity                           group B
# parental level of education    bachelor's degree
# lunch                                   standard
# test preparation course                     none
# math score                                    72
# reading score                                 72
# writing score                                 74
# Name: 0, dtype: object

# %%
ds.iloc[1:5, 2:4]
# Out:
#   parental level of education         lunch
# 1                some college      standard
# 2             master's degree      standard
# 3          associate's degree  free/reduced
# 4                some college      standard

# %%
ds[ds['math score']>90]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 34     male        group E                some college      standard
# 104    male        group C                some college      standard
# 114  female        group E           bachelor's degree      standard
# 121    male        group B          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 171    male        group E            some high school      standard
# 179  female        group D            some high school      standard
# 233    male        group E            some high school      standard
# 263  female        group E                 high school      standard
# 286    male        group E          associate's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# ...

# %%
ds.query("`math score` > 90")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 34     male        group E                some college      standard
# 104    male        group C                some college      standard
# 114  female        group E           bachelor's degree      standard
# 121    male        group B          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 171    male        group E            some high school      standard
# 179  female        group D            some high school      standard
# 233    male        group E            some high school      standard
# 263  female        group E                 high school      standard
# 286    male        group E          associate's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# ...

# %%
ds.sort_values('math score')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 625    male        group D                some college      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# 962  female        group E          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
ds.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
ds.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
ds.fillna(0, inplace= True)

# %%
ds.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
ds.sort_values(by='math score', ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
ds[ds['lunch']=='standard']
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 4      male        group C                some college  standard
# 5    female        group B          associate's degree  standard
# ..      ...            ...                         ...       ...
# 987    male        group E            some high school  standard
# 991  female        group B            some high school  standard
# 994    male        group A                 high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %%
ds['gender'].map({'male':'m','female':'f'})
# Out:
# 0      f
# 1      f
# 2      f
# 3      m
# 4      m
#       ..
# 995    f
# 996    m
# 997    f
# 998    f
# 999    f
# Name: gender, Length: 1000, dtype: object

# %%
ds.iloc[0, 0]
# Out:
# 'female'

# %%
ds[(ds['gender']=='male')&(ds['race/ethnicity']=='group B')]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 7     male        group B                some college  free/reduced
# 26    male        group B                some college      standard
# 39    male        group B          associate's degree  free/reduced
# 43    male        group B                some college  free/reduced
# 45    male        group B          associate's degree      standard
# ..     ...            ...                         ...           ...
# 919   male        group B                some college      standard
# 946   male        group B                 high school      standard
# 948   male        group B            some high school  free/reduced
# 976   male        group B                some college  free/reduced
# 982   male        group B            some high school      standard
#
#     test preparation course  math score  reading score  writing score
# 7                      none          40             43             39
# ...

# %%
ds['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
ds['parental level of education'].nunique()
# Out:
# 6

# %%
ds['reading score'].mean()
# Out:
# 69.169

# %%
ds.loc[:2,['test preparation course','writing score']]
# Out:
#   test preparation course  writing score
# 0                    none             74
# 1               completed             88
# 2                    none             93

# %%
ds.loc[:2,['reading score']]
# Out:
#    reading score
# 0             72
# 1             90
# 2             95

# %%
ds.loc[ds['writing score'] >=90, 'test preparation course'] = "completed"
print(ds.loc[ds['writing score'] >=90])
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 2    female        group B             master's degree  standard
# 6    female        group B                some college  standard
# 94   female        group B                some college  standard
# 104    male        group C                some college  standard
# 106  female        group D             master's degree  standard
# ..      ...            ...                         ...       ...
# 962  female        group E          associate's degree  standard
# 970  female        group D           bachelor's degree  standard
# 979  female        group C          associate's degree  standard
# 983  female        group A                some college  standard
# 995  female        group E             master's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 2                 completed          90             95             93
# ...

# %%
if (ds['race/ethnicity'] == 'group F').any():
    ds.loc[ds['race/ethnicity'] == 'group F', 'lunch'] = "standard"
    print(ds.loc[ds['race/ethnicity'] == 'group F'])  # Print updated row
else:
    print("No row with race/ethnicity == group F found.")
# Out:
# No row with race/ethnicity == group F found.

# %%
ds.iloc[[0,1]]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88

# %%
ds.iloc[[0,5],2]
# Out:
# 0     bachelor's degree
# 5    associate's degree
# Name: parental level of education, dtype: object

# %%
ds.loc[[0,5],['parental level of education','lunch']]
# Out:
#   parental level of education     lunch
# 0           bachelor's degree  standard
# 5          associate's degree  standard

# %%
ds['lunch'].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
ds.loc[[1,4,7],['gender','test preparation course']]
# Out:
#    gender test preparation course
# 1  female               completed
# 4    male                    none
# 7    male                    none

# %%
ds.loc[1:8,['gender','test preparation course']]
# Out:
#    gender test preparation course
# 1  female               completed
# 2  female               completed
# 3    male                    none
# 4    male                    none
# 5  female                    none
# 6  female               completed
# 7    male                    none
# 8    male               completed

# %%
ds.loc[1:8:2,['gender','test preparation course']]
# Out:
#    gender test preparation course
# 1  female               completed
# 3    male                    none
# 5  female                    none
# 7    male                    none

# %%
ds.loc[1:8:2,'gender':'test preparation course']
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 1  female        group C                some college      standard
# 3    male        group A          associate's degree  free/reduced
# 5  female        group B          associate's degree      standard
# 7    male        group B                some college  free/reduced
#
#   test preparation course
# 1               completed
# 3                    none
# 5                    none
# 7                    none

# %%
ds.set_index('parental level of education')
# Out:
#                              gender race/ethnicity         lunch  \
# parental level of education
# bachelor's degree            female        group B      standard
# some college                 female        group C      standard
# master's degree              female        group B      standard
# associate's degree             male        group A  free/reduced
# some college                   male        group C      standard
# ...                             ...            ...           ...
# master's degree              female        group E      standard
# high school                    male        group C  free/reduced
# high school                  female        group C  free/reduced
# some college                 female        group D      standard
# some college                 female        group D  free/reduced
#
#                             test preparation course  math score  \
# parental level of education
# ...

# %%
ds.set_index('gender',inplace=True)

# %%
ds.index
# Out:
# Index(['female', 'female', 'female', 'male', 'male', 'female', 'female',
#        'male', 'male', 'female',
#        ...
#        'male', 'female', 'female', 'female', 'male', 'female', 'male',
#        'female', 'female', 'female'],
#       dtype='object', name='gender', length=1000)

# %%
ds.loc[[2],['lunch','parental level of education']]
# Out:
#       lunch parental level of education
# 2  standard             master's degree

# %%
ds.reset_index(inplace=True)

# %%
ds.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
ds['gender']=='male'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997    False
# 998    False
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
ds.query('gender == "male"')
# Out:
#     gender  level_0  index race/ethnicity parental level of education  \
# 3     male        3      3        group A          associate's degree
# 4     male        4      4        group C                some college
# 7     male        7      7        group B                some college
# 8     male        8      8        group D                 high school
# 10    male       10     10        group C          associate's degree
# ..     ...      ...    ...            ...                         ...
# 985   male      985    985        group A                 high school
# 987   male      987    987        group E            some high school
# 990   male      990    990        group E                 high school
# 994   male      994    994        group A                 high school
# 996   male      996    996        group C                 high school
#
#             lunch test preparation course  math score  reading score  \
# ...

# %%
ds.query('gender == "male"')[['math score','reading score']]
# Out:
#      math score  reading score
# 3            47             57
# 4            76             78
# 7            40             43
# 8            64             64
# 10           58             54
# ..          ...            ...
# 985          57             51
# 987          81             75
# 990          86             81
# 994          63             63
# 996          62             55
#
# [482 rows x 2 columns]

# %%
ds[(ds['race/ethnicity'] == "group A") & (ds['lunch'] == "free/reduced")][['writing score']]
# Out:
#      writing score
# 3               44
# 25              72
# 61              34
# 62              55
# 72              48
# 82              54
# 228             64
# 300             81
# 327             19
# 365             60
# 368             58
# 384             43
# 395             41
# 402             55
# 428             53
# 433             50
# 442             69
# 444             73
# 467             65
# 468             85
# 489             82
# 490             76
# 575             53
# 688             44
# 705             65
# 731             43
# 741             56
# 769             57
# 805             74
# 811             49
# 830             57
# 892             73
# 902             41
# 943             61
# 972             60
# 988             45

# %%
race_ethnicity = ['group A','group D']
filter = ds['race/ethnicity'].isin(race_ethnicity)
ds.loc[filter,'race/ethnicity']
# Out:
# 3      group A
# 8      group D
# 11     group D
# 13     group A
# 14     group A
#         ...
# 992    group D
# 993    group D
# 994    group A
# 998    group D
# 999    group D
# Name: race/ethnicity, Length: 351, dtype: object

# %%
m= ds['parental level of education'].str.contains("associate's degree",na=False)
ds.loc[m,'parental level of education']
# Out:
# 3      associate's degree
# 5      associate's degree
# 10     associate's degree
# 11     associate's degree
# 19     associate's degree
#               ...
# 968    associate's degree
# 977    associate's degree
# 979    associate's degree
# 986    associate's degree
# 992    associate's degree
# Name: parental level of education, Length: 222, dtype: object
